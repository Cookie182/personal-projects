# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec as gs
# %matplotlib inline
plt.style.use('bmh')
from scipy import stats as ss
import seaborn as sns
sns.set_style('dark')
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, RandomizedSearchCV
from sklearn.metrics import f1_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import class_weight

# the big boy stuff
import tensorflow.keras.metrics as metric
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
n = 1000 # number of students
def grades(lower, upper, mean, std, n=n): # get an array of grades in a range and distribution parameters
    return [int(x) for x in (ss.truncnorm.rvs(((lower - mean) / std), ((upper - mean) / std), loc=mean, scale=std, size=n))]

# %% [markdown]
# ### Gathering grades
# #### Labs

# %%
Lab = dict()
for _ in range(1, 9):
    Lab[_] = grades(0, 11, 6, 3)
for key, item in Lab.items():
    print(f"Lab {key} -> {item[:10]}")
# Out:
# Lab 1 -> [6, 9, 2, 6, 1, 9, 4, 7, 5, 10]
# Lab 2 -> [9, 7, 2, 7, 7, 6, 5, 7, 5, 7]
# Lab 3 -> [1, 9, 9, 6, 0, 8, 6, 6, 5, 2]
# Lab 4 -> [10, 7, 6, 7, 7, 7, 3, 2, 3, 10]
# Lab 5 -> [6, 2, 3, 6, 4, 8, 10, 8, 4, 10]
# Lab 6 -> [2, 6, 6, 6, 2, 3, 4, 7, 2, 7]
# Lab 7 -> [5, 8, 5, 7, 9, 5, 9, 7, 10, 4]
# Lab 8 -> [9, 5, 2, 2, 4, 3, 1, 5, 3, 8]

# %%
for _ in range(11):
    print(f"{_} -> {Lab[1].count(_)}")
# Out:
# 0 -> 27
# 1 -> 49
# 2 -> 66
# 3 -> 98
# 4 -> 135
# 5 -> 130
# 6 -> 134
# 7 -> 132
# 8 -> 111
# 9 -> 62
# 10 -> 56

# %%
fig = plt.figure(constrained_layout=True, figsize=(12, 9))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(8):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Lab[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='right', color='blue'), bins=10)
    plt.xticks(range(0, 11))
    ax.set_title(f"Lab {_+1}")
fig.suptitle('Grades for Labs', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Assignments

# %%
Assignment = dict()
for _ in range(1, 5):
    Assignment[_] = grades(0, 11, 7, 3)
for key, item in Assignment.items():
    print(f"Assignment {key} -> {item[:10]}")
# Out:
# Assignment 1 -> [9, 5, 6, 4, 6, 8, 7, 6, 10, 4]
# Assignment 2 -> [8, 7, 3, 5, 10, 3, 2, 7, 3, 5]
# Assignment 3 -> [1, 3, 5, 4, 5, 2, 3, 4, 5, 4]
# Assignment 4 -> [9, 5, 8, 5, 2, 3, 5, 10, 5, 7]

# %%
for _ in range(11):
    print(f"{_} -> {Assignment[1].count(_)}")
# Out:
# 0 -> 13
# 1 -> 33
# 2 -> 40
# 3 -> 75
# 4 -> 107
# 5 -> 124
# 6 -> 153
# 7 -> 137
# 8 -> 121
# 9 -> 113
# 10 -> 84

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 14))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(4):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Assignment[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=10)
    ax.set_title(f"Assignment {_+1}")
    plt.xticks(range(0, 11))
fig.suptitle('Grades for Assignments', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Mid-Terms

# %%
Mid_term = dict()
for _ in range(1, 3):
    Mid_term[_] = grades(0, 101, 70, 35)
for key, item in Mid_term.items():
    print(f"Mid-Term {key} -> {item[:10]}")
# Out:
# Mid-Term 1 -> [89, 73, 87, 74, 74, 58, 86, 64, 47, 69]
# Mid-Term 2 -> [67, 61, 53, 93, 96, 46, 76, 65, 100, 80]

# %%
rang = ['1-10', '11-20']
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Mid_term[1].count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 11
# 10-20 -> 44
# 20-30 -> 66
# 30-40 -> 77
# 40-50 -> 44
# 50-60 -> 110
# 60-70 -> 121
# 70-80 -> 110
# 80-90 -> 264
# 90-100 -> 176

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 6))
grid = gs(nrows=1, ncols=2, figure=fig)
for _ in range(2):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Mid_term[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
    ax.set_title(f"Mid-Term {_+1}")
fig.suptitle('Grades for Mid-Terms', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Final Exam

# %%
Final = grades(0, 101, 65, 30)
print(f"Final Exam -> {Final[:10]}")
# Out:
# Final Exam -> [21, 64, 43, 70, 48, 25, 87, 90, 56, 86]

# %%
rang = ['1-10', '11-20']
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Final.count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 11
# 10-20 -> 44
# 20-30 -> 44
# 30-40 -> 44
# 40-50 -> 77
# 50-60 -> 110
# 60-70 -> 154
# 70-80 -> 253
# 80-90 -> 209
# 90-100 -> 121

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Final, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
plt.show()

# %% [markdown]
# ### Grade Weights
# Each type of test will contribute this much to the final grade:
# * Final Exam = 30%
# * Mid-Terms = 30%
# * Assignments = 20%
# * Labs = 20%
#
# Total passing percentage is assumed to be **60%**

# %% [markdown]
# ### Making the DataFrame
# #### Combining the marks togethe

# %%
df = pd.DataFrame(index=range(1, n+1))
df.index.name = 'Student'

# automate the process of inputting the grades for all tests for each student
for _ in range(1, 9):
    df[f"Lab {_}"] = Lab[_]

for _ in range(1, 5):
    df[f"Assignment {_}"] = Assignment[_]
    
for _ in range(1, 3):
    df[f"Mid-Term {_}"] = Mid_term[_]
    
df['Final'] = Final
    
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            6      9      1     10      6      2      5      9             9
# 2            9      7      9      7      2      6      8      5             5
# 3            2      2      9      6      3      6      5      2             6
# 4            6      7      6      7      6      6      7      2             4
# 5            1      7      0      7      4      2      9      4             6
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   8             1             9          89          67
# 2                   7             3             5          73          61
# 3                   3             5             8          87          53
# 4                   5             4             5          74          93
# 5                  10             5             2          74          96
#
#          Final
# Student
# 1           21
# 2           64
# 3           43
# 4           70
# 5           48

# %%
print(f"No. of students -> {len(df)}\nNumber of tests -> {df.shape[1]}")
# Out:
# No. of students -> 1000
# Number of tests -> 15

# %% [markdown]
# #### Determining if a student passes

# %%
Final_percent = 0.3
Mid_term_percent = 0.3
Assignments_percent = 0.2
Labs_percent = 0.2

# %% [markdown]
# Calculate the total grade for each category of test, then use that total and calculate the overall percentage of how much it contributes to students (based on the test's weightage) **overall** grade

# %%
lab_grades = list(df.iloc[:, :8].apply(lambda x: np.sum(x) / 80, axis=1) * Labs_percent)
assignment_grades = list(df.iloc[:, 8:12].apply(lambda x: np.sum(x) / 40, axis=1) * Assignments_percent)
mid_term_grades = list(df.iloc[:, 12:14].apply(lambda x: np.sum(x) / 200, axis=1) * Mid_term_percent)
final_grades = list(df.Final.apply(lambda x: (x / 100) * Final_percent))
lab_grades[:10]
# Out:
# [0.12,
#  0.1325,
#  0.08750000000000001,
#  0.11750000000000001,
#  0.085,
#  0.12250000000000001,
#  0.10500000000000001,
#  0.12250000000000001,
#  0.09250000000000001,
#  0.145]

# %%
overall_grades = [] # calculate the total grade percentage
for _ in range(n):
    overall_grades.append(np.round((lab_grades[_] + assignment_grades[_] + mid_term_grades[_] + final_grades[_]) * 100, 2))
overall_grades[:10]
# Out:
# [55.2, 62.55, 53.65, 66.8, 59.9, 43.35, 69.4, 72.1, 59.6, 72.65]

# %% [markdown]
# #### Finishing the final table

# %%
df['Total'] = overall_grades
df['Pass/Fail'] = ["Pass" if x >= 60 else "Fail" for x in overall_grades]
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            6      9      1     10      6      2      5      9             9
# 2            9      7      9      7      2      6      8      5             5
# 3            2      2      9      6      3      6      5      2             6
# 4            6      7      6      7      6      6      7      2             4
# 5            1      7      0      7      4      2      9      4             6
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   8             1             9          89          67
# 2                   7             3             5          73          61
# 3                   3             5             8          87          53
# 4                   5             4             5          74          93
# 5                  10             5             2          74          96
#
#          Final  Total Pass/Fail
# Student
# 1           21  55.20      Fail
# 2           64  62.55      Pass
# 3           43  53.65      Fail
# 4           70  66.80      Pass
# 5           48  59.90      Fail

# %%
print(f"Students failed -> {len(df[df['Pass/Fail'] == 'Fail'])}\nStudents passed -> {len(df[df['Pass/Fail'] == 'Pass'])}")
# Out:
# Students failed -> 528
# Students passed -> 472

# %%
df.describe().drop(['count', '25%', '50%', '75%'])
# Out:
#           Lab 1      Lab 2      Lab 3     Lab 4      Lab 5     Lab 6  \
# mean   5.399000   5.340000   5.406000   5.30700   5.360000   5.33200
# std    2.545639   2.534329   2.474932   2.51696   2.550864   2.47546
# min    0.000000   0.000000   0.000000   0.00000   0.000000   0.00000
# max   10.000000  10.000000  10.000000  10.00000  10.000000  10.00000
#
#           Lab 7      Lab 8  Assignment 1  Assignment 2  Assignment 3  \
# mean   5.323000   5.371000      6.088000      6.076000      6.027000
# std    2.562272   2.484257      2.477982      2.500896      2.504105
# min    0.000000   0.000000      0.000000      0.000000      0.000000
# max   10.000000  10.000000     10.000000     10.000000     10.000000
#
#       Assignment 4  Mid-Term 1  Mid-Term 2       Final     Total
# mean      5.845000   60.357000   60.731000   59.785000  58.82620
# std       2.465168   24.421424   25.159365   22.083987   8.95392
# min       0.000000    0.000000    0.000000    0.000000  28.65000
# max      10.000000  100.000000  100.000000  100.000000  84.20000

# %% [markdown]
# ### Creating excel file

# %%
df.to_excel("Grades.xlsx", sheet_name='Grades')

# %% [markdown]
# ### Making the Classifier
# #### Preprocessing

# %%
df_cf = df.copy()
df_cf.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            6      9      1     10      6      2      5      9             9
# 2            9      7      9      7      2      6      8      5             5
# 3            2      2      9      6      3      6      5      2             6
# 4            6      7      6      7      6      6      7      2             4
# 5            1      7      0      7      4      2      9      4             6
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   8             1             9          89          67
# 2                   7             3             5          73          61
# 3                   3             5             8          87          53
# 4                   5             4             5          74          93
# 5                  10             5             2          74          96
#
#          Final  Total Pass/Fail
# Student
# 1           21  55.20      Fail
# 2           64  62.55      Pass
# 3           43  53.65      Fail
# 4           70  66.80      Pass
# 5           48  59.90      Fail

# %%
df_cf_y = LabelEncoder().fit_transform(df_cf['Pass/Fail'])
df_cf.drop(['Final', 'Total', 'Pass/Fail'], axis=1, inplace=True)
scaler = StandardScaler().fit(df_cf)
df_cf_x = scaler.transform(df_cf)
df_cf_x[0]
# Out:
# array([ 0.23620814,  1.44489195, -1.7811416 ,  1.86548409,  0.25102093,
#        -1.34668578, -0.12612309,  1.46153016,  1.17573764,  0.76970937,
#        -2.00850823,  1.28047216,  1.1734505 ,  0.24929631])

# %%
df_cf_x_train, df_cf_x_test, df_cf_y_train, df_cf_y_test = train_test_split(df_cf_x, df_cf_y, stratify=df_cf_y, 
                                                                           test_size=.10, random_state=7)
print(f"Train X -> {df_cf_x_train.shape}\nTrain y -> {df_cf_y_train.shape}")
print(f"Test X -> {df_cf_x_test.shape}\nTest y -> {df_cf_y_test.shape}")
# Out:
# Train X -> (900, 14)
# Train y -> (900,)
# Test X -> (100, 14)
# Test y -> (100,)

# %% [markdown]
# #### Setting up the models
# ##### RandomForestClassifier

# %%
rfc = RandomizedSearchCV(estimator=RandomForestClassifier(),
                  param_distributions={'n_estimators':range(500, 1250, 100), 
                                       'warm_start':[True], 'criterion':['entropy']},
                  n_jobs=-1, cv=RepeatedStratifiedKFold(random_state=7), 
                  return_train_score=True, verbose=3, n_iter=100, refit=True)
rfc.fit(df_cf_x_train, df_cf_y_train)
rfc.best_params_
# Out:
# Fitting 50 folds for each of 8 candidates, totalling 400 fits
# {'warm_start': True, 'n_estimators': 700, 'criterion': 'entropy'}

# %%
plt.figure(figsize=(8, 5))
plt.title(f"RandomForestClassifier score -> {rfc.score(df_cf_x_test, df_cf_y_test)}")
plt.plot(range(500, 1250, 100), 
         pd.DataFrame(rfc.cv_results_)['mean_test_score'][pd.DataFrame(rfc.cv_results_)['param_criterion'] == 'entropy'], 
         label='Entropy Test', c='red')
plt.xlabel('Estimators')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### LogisticRegressionCV

# %%
logreg = LogisticRegressionCV(cv=RepeatedStratifiedKFold(n_splits=10, random_state=7), 
                             max_iter=1000, n_jobs=-1, verbose=3, refit=True, random_state=7).fit(df_cf_x_train, 
                                                                                                  df_cf_y_train)
logreg.score(df_cf_x_test, df_cf_y_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    2.8s finished
# 0.77

# %% [markdown]
# ##### KNeighborsClassifier

# %%
knn = RandomizedSearchCV(estimator=KNeighborsClassifier(), param_distributions={'n_neighbors':range(10, 21), 
                                                                'weights':['uniform', 'distance'], 
                                                                'n_jobs':[-1]}, 
                  cv=RepeatedStratifiedKFold(random_state=7), n_jobs=-1, return_train_score=True, 
                         verbose=3, refit=True, n_iter=100)
knn.fit(df_cf_x_train, df_cf_y_train)
knn.best_params_
# Out:
# Fitting 50 folds for each of 22 candidates, totalling 1100 fits
# {'weights': 'distance', 'n_neighbors': 15, 'n_jobs': -1}

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(10, 21), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'distance'],
        label='Distance Weight', c='red')
plt.plot(range(10, 21), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'uniform'], 
        label='Uniform Weight', c='black')
plt.title(f"KNeighborsClassifier -> {knn.score(df_cf_x_test, df_cf_y_test)}")
plt.xlabel('N Neighbors')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Naive-Bayes Classifier

# %%
gnb = GaussianNB().partial_fit(df_cf_x_train, df_cf_y_train, np.unique(df_cf_y_train))
gnb.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.76

# %% [markdown]
# ##### Decision Tree Classifier (for fun, not to be used for actual predictions, instead just to have a quick look at the decision tree)

# %%
dtc = DecisionTreeClassifier(criterion='entropy').fit(df_cf_x_train, df_cf_y_train)
dtc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.62

# %%
fig = plt.figure(figsize=(12, 8))
dtc_tree = tree.plot_tree(dtc, feature_names=df_cf.columns, class_names=['Pass', 'Fail'], filled=True, rounded=True,
                         fontsize=3)

# %% [markdown]
# ##### Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(n_estimators=100, max_depth=6, random_state=7, verbose=3, warm_start=True,
                                n_iter_no_change=30).fit(df_cf_x_train, df_cf_y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2994            0.35s
#          2           1.2312            0.37s
#          3           1.1651            0.34s
#          4           1.1152            0.35s
#          5           1.0668            0.35s
#          6           1.0205            0.35s
#          7           0.9770            0.35s
#          8           0.9427            0.35s
#          9           0.9083            0.35s
#         10           0.8727            0.34s
#         11           0.8332            0.34s
#         12           0.8031            0.33s
#         13           0.7743            0.33s
#         14           0.7541            0.33s
#         15           0.7322            0.32s
#         16           0.7155            0.32s
#         17           0.6947            0.32s
#         18           0.6750            0.31s
#         19           0.6586            0.31s
#         20           0.6369            0.31s
#         21           0.6217            0.30s
#         22           0.6051            0.30s
#         23           0.5902            0.30s
#         24           0.5763            0.29s
#         25           0.5652            0.29s
#         26           0.5481            0.28s
#         27           0.5301            0.28s
#         28           0.5149            0.28s
#         29           0.5068            0.27s
#         30           0.4952            0.27s
#         31           0.4788            0.26s
#         32           0.4697            0.26s
#         33           0.4573            0.25s
#         34           0.4448            0.25s
#         35           0.4299            0.25s
#         36           0.4210            0.24s
#         37           0.4118            0.24s
#         38           0.3992            0.23s
#         39           0.3946            0.23s
#         40           0.3846            0.22s
#         41           0.3747            0.22s
#         42           0.3670            0.22s
#         43           0.3505            0.21s
#         44           0.3409            0.21s
#         45           0.3329            0.20s
#         46           0.3263            0.20s
#         47           0.3186            0.20s
#         48           0.3155            0.19s
#         49           0.3082            0.19s
#         50           0.3033            0.19s
#         51           0.2989            0.18s

# %%
gbc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.68

# %% [markdown]
# ####  Evaluating models

# %%
models = pd.DataFrame(index=['RandomForestClassifier', 'LogisticRegressionCV', 'KNeighborsClassifier', 
                      'GaussianNB', 'GradientBoosting'])
models.index.name="Algorithms"
models['Score'] = np.round([rfc.score(df_cf_x_test, df_cf_y_test), logreg.score(df_cf_x_test, df_cf_y_test), 
                  knn.score(df_cf_x_test, df_cf_y_test), gnb.score(df_cf_x_test, df_cf_y_test), 
                  gbc.score(df_cf_x_test, df_cf_y_test)], 4) * 100
models['f1 Score'] = np.round([f1_score(df_cf_y_test, rfc.predict(df_cf_x_test)), 
                      f1_score(df_cf_y_test, logreg.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, knn.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gnb.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gbc.predict(df_cf_x_test))], 4) * 100
models['Used Model'] = [rfc, logreg, knn, gnb, gbc]
models = models.sort_values(["Score", 'f1 Score'], ascending=False)
models
# Out:
#                         Score  f1 Score  \
# Algorithms
# LogisticRegressionCV     77.0     75.79
# GaussianNB               76.0     75.00
# RandomForestClassifier   70.0     67.39
# KNeighborsClassifier     69.0     66.67
# GradientBoosting         68.0     63.64
#
#                                                                Used Model
# Algorithms
# LogisticRegressionCV    LogisticRegressionCV(cv=RepeatedStratifiedKFol...
# GaussianNB                                                   GaussianNB()
# RandomForestClassifier  RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# KNeighborsClassifier    RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# GradientBoosting        ([DecisionTreeRegressor(criterion='friedman_ms...

# %%
models_list = [rfc, logreg, knn, gnb, gbc]
model_names = ['RandomForestClassifier', 'LogisticRegressionCV', 'KNearestNeighbors', 
               'GaussianNB', 'GradientBoosting']
fig = plt.figure(constrained_layout=True, figsize=(12, 8))
grid = gs(nrows=1, ncols=len(models), figure=fig)
for _ in range(len(models)):
    ax = fig.add_subplot(grid[_])
    plt.rcParams.update({'font.size':13})
    plot_confusion_matrix(models_list[_], df_cf_x_test, df_cf_y_test, labels=[0, 1],
                         display_labels=['Fail', 'Pass'], colorbar=False, ax=ax, cmap='afmhot')
    plt.title(f"{model_names[_]}", fontsize=13)
    
plt.show()

# %% [markdown]
# ### Example

# %%
Lab_1 = 7
Lab_2 = 6
Lab_3 = 6
Lab_4 = 9
Lab_5 = 6
Lab_6 = 8
Lab_7 = 5
Lab_8 = 3

Asgn_1 = 6
Asgn_2 = 7
Asgn_3 = 4
Asgn_4 = 5

MT_1 = 45
MT_2 = 65

test = [Lab_1, Lab_2, Lab_3, Lab_4, Lab_5, Lab_6, Lab_7, Lab_8,
       Asgn_1, Asgn_2, Asgn_3, Asgn_4,
       MT_1, MT_2]

# %%
def calculate(test):
    test = scaler.transform(np.array(test).reshape(1, -1)) # scaling scores 
    
    test_ = [0] * len(test[0]) # making dummy list to cummulatively add each test score
    probabs = [] # to store each probability as each test score gets entered
    for x in range(len(test[0])):
        test_[x] = test[0][x]
        probabs.append(models.iloc[0]['Used Model'].predict_proba(np.array([test_]))[0][1] * 100)
    
    pf = None
    if models.iloc[0]['Used Model'].predict(test) == 0:
        pf = 'Fail'
    else:
        pf = 'Pass'
        
    plt.figure(figsize=(8,7))
    plt.title(f"Probability of passing after each test taken\nPredicted Pass or Fail? -> {pf}\
    \nChance of passing -> {models.iloc[0]['Used Model'].predict_proba(test)[0][1] * 100:.2f}%", fontsize=15)
    plt.plot(['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4', 'Lab 5', 'Lab 6', 'Lab 7', 'Lab 8',
             'Asgn 1', 'Asgn 2', 'Asgn 3', 'Asgn 4',
             'MT 1', 'MT 2'], probabs, c='black', linestyle='--', label='Student probability')
    plt.axhline(50, color='red', label='Passing threshold')
    plt.xticks(rotation=45)
    plt.ylabel('Probability (%)')
    plt.margins(0.02, 0.02)
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
    
    return 'Thank you for using this program!'
calculate(test)
# Out:
# 'Thank you for using this program!'

# %% [markdown]
# ### Experimenting Neural Network

# %%
def neural_model():
    neural_model = Sequential([Dense(14, input_dim=14), Activation('relu'),
                   Dense(64), Activation('relu'),
                   Dense(32), Activation('relu'),
                   Dense(1), Activation('sigmoid')])
    neural_model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
    return neural_model

early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=10, 
                                                  mode='max', restore_best_weights=True)

scikit_neural = KerasClassifier(build_fn=neural_model)
scikit_neural.fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=1, 
                                  use_multiprocessing=True, validation_data=(df_cf_x_test, df_cf_y_test), 
                                  callbacks=early_stopping)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 22ms/step - loss: 0.6918 - accuracy: 0.5205 - val_loss: 0.6673 - val_accuracy: 0.6100
# Epoch 2/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6658 - accuracy: 0.5879 - val_loss: 0.6442 - val_accuracy: 0.6300
# Epoch 3/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6449 - accuracy: 0.6395 - val_loss: 0.6260 - val_accuracy: 0.6500
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6297 - accuracy: 0.6526 - val_loss: 0.6106 - val_accuracy: 0.6500
# Epoch 5/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.6453 - val_loss: 0.5950 - val_accuracy: 0.7200
# Epoch 6/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6049 - accuracy: 0.6800 - val_loss: 0.5825 - val_accuracy: 0.7200
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5745 - accuracy: 0.7028 - val_loss: 0.5767 - val_accuracy: 0.7100
# Epoch 8/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6043 - accuracy: 0.6557 - val_loss: 0.5719 - val_accuracy: 0.7100
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5652 - accuracy: 0.7034 - val_loss: 0.5605 - val_accuracy: 0.7100
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.6826 - val_loss: 0.5501 - val_accuracy: 0.7300
# Epoch 11/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5491 - accuracy: 0.7064 - val_loss: 0.5452 - val_accuracy: 0.7200
# Epoch 12/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 0.7128 - val_loss: 0.5336 - val_accuracy: 0.7400
# Epoch 13/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5273 - accuracy: 0.7172 - val_loss: 0.5343 - val_accuracy: 0.7400
# Epoch 14/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 0.7137 - val_loss: 0.5298 - val_accuracy: 0.7300
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5377 - accuracy: 0.7078 - val_loss: 0.5379 - val_accuracy: 0.7200
# Epoch 16/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5182 - accuracy: 0.7370 - val_loss: 0.5376 - val_accuracy: 0.7600
# Epoch 17/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5367 - accuracy: 0.7052 - val_loss: 0.5345 - val_accuracy: 0.7700
# Epoch 18/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5182 - accuracy: 0.7299 - val_loss: 0.5329 - val_accuracy: 0.7300
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5136 - accuracy: 0.7314 - val_loss: 0.5342 - val_accuracy: 0.7300
# Epoch 20/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5091 - accuracy: 0.7455 - val_loss: 0.5256 - val_accuracy: 0.7600
# Epoch 21/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7554 - val_loss: 0.5248 - val_accuracy: 0.7700
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5252 - accuracy: 0.7295 - val_loss: 0.5267 - val_accuracy: 0.7400
# Epoch 23/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.7660 - val_loss: 0.5387 - val_accuracy: 0.7700
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7474 - val_loss: 0.5261 - val_accuracy: 0.7500
# Epoch 25/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.7395 - val_loss: 0.5195 - val_accuracy: 0.7600
# Epoch 26/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4979 - accuracy: 0.7552 - val_loss: 0.5300 - val_accuracy: 0.7600
# Epoch 27/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4860 - accuracy: 0.7385 - val_loss: 0.5415 - val_accuracy: 0.7300
# Restoring model weights from the end of the best epoch.
# Epoch 00027: early stopping

# %%
print("f1_score =", f1_score(df_cf_y_test, scikit_neural.predict(df_cf_x_test)))
print("Accuracy =", scikit_neural.score(df_cf_x_test, df_cf_y_test))
# Out:
# f1_score = 0.7676767676767676
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5345 - accuracy: 0.7700
# Accuracy = 0.7699999809265137

# %%
print(f"Neural Network probability of passing ->\
 {scikit_neural.predict_proba(scaler.transform(np.array(test).reshape(1, -1)))[0][1]*100:.2f}%")
# Out:
# Neural Network probability of passing -> 34.39%

# %%
neural_model().summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 14)                210
# _________________________________________________________________
# activation_4 (Activation)    (None, 14)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                960
# _________________________________________________________________
# activation_5 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_6 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,283
# Trainable params: 3,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
pd.DataFrame(neural_model().fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=0,
                       validation_data=(df_cf_x_test, df_cf_y_test), callbacks=early_stopping).history).plot()
plt.show()
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping

# %%
_ = metric.FalseNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('False Negatives =', _.result().numpy())

_ = metric.TrueNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('True Negatives =', _.result().numpy())
# Out:
# False Negatives = 9.0
# True Negatives = 39.0
