# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec as gs
# %matplotlib inline
plt.style.use('bmh')
from scipy import stats as ss
import seaborn as sns
sns.set_style('dark')
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, RandomizedSearchCV
from sklearn.metrics import f1_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import class_weight

# the big boy stuff
import tensorflow.keras.metrics as metric
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
n = 1000 # number of students
def grades(lower, upper, mean, std, n=n): # get an array of grades in a range and distribution parameters
    return [int(x) for x in (ss.truncnorm.rvs(((lower - mean) / std), ((upper - mean) / std), loc=mean, scale=std, size=n))]

# %% [markdown]
# ### Gathering grades
# #### Labs

# %%
Lab = dict()
for _ in range(1, 9):
    Lab[_] = grades(0, 11, 6, 3)
for key, item in Lab.items():
    print(f"Lab {key} -> {item[:10]}")
# Out:
# Lab 1 -> [7, 4, 0, 2, 8, 10, 2, 4, 4, 5]
# Lab 2 -> [2, 2, 5, 9, 7, 4, 10, 3, 3, 4]
# Lab 3 -> [7, 3, 3, 5, 4, 3, 6, 6, 2, 5]
# Lab 4 -> [1, 4, 5, 6, 6, 7, 10, 4, 4, 2]
# Lab 5 -> [5, 2, 3, 5, 10, 7, 2, 1, 3, 8]
# Lab 6 -> [6, 8, 8, 9, 4, 5, 4, 7, 6, 9]
# Lab 7 -> [8, 5, 3, 3, 4, 6, 5, 2, 7, 0]
# Lab 8 -> [7, 4, 4, 5, 7, 3, 9, 2, 3, 7]

# %%
for _ in range(11):
    print(f"{_} -> {Lab[1].count(_)}")
# Out:
# 0 -> 26
# 1 -> 37
# 2 -> 78
# 3 -> 99
# 4 -> 126
# 5 -> 134
# 6 -> 164
# 7 -> 113
# 8 -> 98
# 9 -> 70
# 10 -> 55

# %%
fig = plt.figure(constrained_layout=True, figsize=(12, 9))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(8):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Lab[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='right', color='blue'), bins=10)
    plt.xticks(range(0, 11))
    ax.set_title(f"Lab {_+1}")
fig.suptitle('Grades for Labs', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Assignments

# %%
Assignment = dict()
for _ in range(1, 5):
    Assignment[_] = grades(0, 11, 7, 3)
for key, item in Assignment.items():
    print(f"Assignment {key} -> {item[:10]}")
# Out:
# Assignment 1 -> [7, 5, 4, 6, 10, 8, 10, 5, 9, 4]
# Assignment 2 -> [6, 10, 10, 3, 7, 10, 7, 9, 10, 9]
# Assignment 3 -> [9, 5, 4, 10, 4, 8, 8, 4, 6, 4]
# Assignment 4 -> [10, 7, 3, 5, 9, 8, 3, 7, 9, 6]

# %%
for _ in range(11):
    print(f"{_} -> {Assignment[1].count(_)}")
# Out:
# 0 -> 14
# 1 -> 31
# 2 -> 42
# 3 -> 72
# 4 -> 103
# 5 -> 128
# 6 -> 159
# 7 -> 131
# 8 -> 132
# 9 -> 111
# 10 -> 77

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 14))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(4):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Assignment[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=10)
    ax.set_title(f"Assignment {_+1}")
    plt.xticks(range(0, 11))
fig.suptitle('Grades for Assignments', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Mid-Terms

# %%
Mid_term = dict()
for _ in range(1, 3):
    Mid_term[_] = grades(0, 101, 70, 35)
for key, item in Mid_term.items():
    print(f"Mid-Term {key} -> {item[:10]}")
# Out:
# Mid-Term 1 -> [65, 64, 54, 77, 45, 76, 100, 0, 65, 62]
# Mid-Term 2 -> [58, 73, 95, 80, 53, 55, 26, 100, 38, 78]

# %%
rang = ['1-10', '11-20']
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Mid_term[1].count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 44
# 10-20 -> 33
# 20-30 -> 44
# 30-40 -> 66
# 40-50 -> 132
# 50-60 -> 176
# 60-70 -> 88
# 70-80 -> 187
# 80-90 -> 198
# 90-100 -> 99

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 6))
grid = gs(nrows=1, ncols=2, figure=fig)
for _ in range(2):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Mid_term[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
    ax.set_title(f"Mid-Term {_+1}")
fig.suptitle('Grades for Mid-Terms', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Final Exam

# %%
Final = grades(0, 101, 65, 30)
print(f"Final Exam -> {Final[:10]}")
# Out:
# Final Exam -> [30, 18, 16, 38, 87, 61, 60, 31, 96, 74]

# %%
rang = ['1-10', '11-20']
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Final.count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 0
# 10-20 -> 11
# 20-30 -> 88
# 30-40 -> 132
# 40-50 -> 110
# 50-60 -> 165
# 60-70 -> 198
# 70-80 -> 110
# 80-90 -> 121
# 90-100 -> 66

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Final, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
plt.show()

# %% [markdown]
# ### Grade Weights
# Each type of test will contribute this much to the final grade:
# * Final Exam = 30%
# * Mid-Terms = 30%
# * Assignments = 20%
# * Labs = 20%
#
# Total passing percentage is assumed to be **60%**

# %% [markdown]
# ### Making the DataFrame
# #### Combining the marks togethe

# %%
df = pd.DataFrame(index=range(1, n+1))
df.index.name = 'Student'

# automate the process of inputting the grades for all tests for each student
for _ in range(1, 9):
    df[f"Lab {_}"] = Lab[_]

for _ in range(1, 5):
    df[f"Assignment {_}"] = Assignment[_]
    
for _ in range(1, 3):
    df[f"Mid-Term {_}"] = Mid_term[_]
    
df['Final'] = Final
    
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            7      2      7      1      5      6      8      7             7
# 2            4      2      3      4      2      8      5      4             5
# 3            0      5      3      5      3      8      3      4             4
# 4            2      9      5      6      5      9      3      5             6
# 5            8      7      4      6     10      4      4      7            10
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   6             9            10          65          58
# 2                  10             5             7          64          73
# 3                  10             4             3          54          95
# 4                   3            10             5          77          80
# 5                   7             4             9          45          53
#
#          Final
# Student
# 1           30
# 2           18
# 3           16
# 4           38
# 5           87

# %%
print(f"No. of students -> {len(df)}\nNumber of tests -> {df.shape[1]}")
# Out:
# No. of students -> 1000
# Number of tests -> 15

# %% [markdown]
# #### Determining if a student passes

# %%
Final_percent = 0.3
Mid_term_percent = 0.3
Assignments_percent = 0.2
Labs_percent = 0.2

# %% [markdown]
# Calculate the total grade for each category of test, then use that total and calculate the overall percentage of how much it contributes to students (based on the test's weightage) **overall** grade

# %%
lab_grades = list(df.iloc[:, :8].apply(lambda x: np.sum(x) / 80, axis=1) * Labs_percent)
assignment_grades = list(df.iloc[:, 8:12].apply(lambda x: np.sum(x) / 40, axis=1) * Assignments_percent)
mid_term_grades = list(df.iloc[:, 12:14].apply(lambda x: np.sum(x) / 200, axis=1) * Mid_term_percent)
final_grades = list(df.Final.apply(lambda x: (x / 100) * Final_percent))
lab_grades[:10]
# Out:
# [0.1075,
#  0.08000000000000002,
#  0.07750000000000001,
#  0.11000000000000001,
#  0.125,
#  0.1125,
#  0.12,
#  0.0725,
#  0.08000000000000002,
#  0.1]

# %%
overall_grades = [] # calculate the total grade percentage
for _ in range(n):
    overall_grades.append(np.round((lab_grades[_] + assignment_grades[_] + mid_term_grades[_] + final_grades[_]) * 100, 2))
overall_grades[:10]
# Out:
# [54.2, 47.45, 45.4, 57.95, 68.3, 66.2, 62.9, 44.05, 69.25, 64.7]

# %% [markdown]
# #### Finishing the final table

# %%
df['Total'] = overall_grades
df['Pass/Fail'] = ["Pass" if x >= 60 else "Fail" for x in overall_grades]
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            7      2      7      1      5      6      8      7             7
# 2            4      2      3      4      2      8      5      4             5
# 3            0      5      3      5      3      8      3      4             4
# 4            2      9      5      6      5      9      3      5             6
# 5            8      7      4      6     10      4      4      7            10
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   6             9            10          65          58
# 2                  10             5             7          64          73
# 3                  10             4             3          54          95
# 4                   3            10             5          77          80
# 5                   7             4             9          45          53
#
#          Final  Total Pass/Fail
# Student
# 1           30  54.20      Fail
# 2           18  47.45      Fail
# 3           16  45.40      Fail
# 4           38  57.95      Fail
# 5           87  68.30      Pass

# %%
print(f"Students failed -> {len(df[df['Pass/Fail'] == 'Fail'])}\nStudents passed -> {len(df[df['Pass/Fail'] == 'Pass'])}")
# Out:
# Students failed -> 547
# Students passed -> 453

# %%
df.describe().drop(['count', '25%', '50%', '75%'])
# Out:
#           Lab 1      Lab 2      Lab 3      Lab 4      Lab 5      Lab 6  \
# mean   5.403000   5.401000   5.282000   5.336000   5.334000   5.293000
# std    2.510556   2.550825   2.404633   2.506269   2.582075   2.506678
# min    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# max   10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
#
#          Lab 7      Lab 8  Assignment 1  Assignment 2  Assignment 3  \
# mean   5.28900   5.300000      6.079000      6.014000      5.949000
# std    2.59735   2.488412      2.455359      2.533816      2.486077
# min    0.00000   0.000000      0.000000      0.000000      0.000000
# max   10.00000  10.000000     10.000000     10.000000     10.000000
#
#       Assignment 4  Mid-Term 1  Mid-Term 2       Final      Total
# mean      5.950000   60.085000   61.206000   59.084000  58.574350
# std       2.430104   24.478868   24.124086   22.970864   9.056957
# min       0.000000    0.000000    0.000000    2.000000  31.700000
# max      10.000000  100.000000  100.000000  100.000000  84.500000

# %% [markdown]
# ### Creating excel file

# %%
df.to_excel("Grades.xlsx", sheet_name='Grades')

# %% [markdown]
# ### Making the Classifier
# #### Preprocessing

# %%
df_cf = df.copy()
df_cf.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            7      2      7      1      5      6      8      7             7
# 2            4      2      3      4      2      8      5      4             5
# 3            0      5      3      5      3      8      3      4             4
# 4            2      9      5      6      5      9      3      5             6
# 5            8      7      4      6     10      4      4      7            10
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   6             9            10          65          58
# 2                  10             5             7          64          73
# 3                  10             4             3          54          95
# 4                   3            10             5          77          80
# 5                   7             4             9          45          53
#
#          Final  Total Pass/Fail
# Student
# 1           30  54.20      Fail
# 2           18  47.45      Fail
# 3           16  45.40      Fail
# 4           38  57.95      Fail
# 5           87  68.30      Pass

# %%
df_cf_y = LabelEncoder().fit_transform(df_cf['Pass/Fail'])
df_cf.drop(['Final', 'Total', 'Pass/Fail'], axis=1, inplace=True)
scaler = StandardScaler().fit(df_cf)
df_cf_x = scaler.transform(df_cf)
df_cf_x[0]
# Out:
# array([ 0.63643224, -1.33396153,  0.71481173, -1.73092723, -0.12941806,
#         0.28218773,  1.04427854,  0.68350857,  0.37528559, -0.00552803,
#         1.22784872,  1.66742927,  0.20088589, -0.13296272])

# %%
df_cf_x_train, df_cf_x_test, df_cf_y_train, df_cf_y_test = train_test_split(df_cf_x, df_cf_y, stratify=df_cf_y, 
                                                                           test_size=.10, random_state=7)
print(f"Train X -> {df_cf_x_train.shape}\nTrain y -> {df_cf_y_train.shape}")
print(f"Test X -> {df_cf_x_test.shape}\nTest y -> {df_cf_y_test.shape}")
# Out:
# Train X -> (900, 14)
# Train y -> (900,)
# Test X -> (100, 14)
# Test y -> (100,)

# %% [markdown]
# #### Setting up the models
# ##### RandomForestClassifier

# %%
rfc = RandomizedSearchCV(estimator=RandomForestClassifier(),
                  param_distributions={'n_estimators':range(500, 1050, 100), 
                                       'warm_start':[True], 'criterion':['entropy']},
                  n_jobs=-1, cv=RepeatedStratifiedKFold(random_state=7), 
                  return_train_score=True, verbose=3, n_iter=100, refit=True)
rfc.fit(df_cf_x_train, df_cf_y_train)
rfc.best_params_
# Out:
# Fitting 50 folds for each of 6 candidates, totalling 300 fits
# {'warm_start': True, 'n_estimators': 1000, 'criterion': 'entropy'}

# %%
plt.figure(figsize=(8, 5))
plt.title(f"RandomForestClassifier score -> {rfc.score(df_cf_x_test, df_cf_y_test)}")
plt.plot(range(500, 1050, 100), 
         pd.DataFrame(rfc.cv_results_)['mean_test_score'][pd.DataFrame(rfc.cv_results_)['param_criterion'] == 'entropy'], 
         label='Entropy Test', c='red')
plt.xlabel('Estimators')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### LogisticRegressionCV

# %%
logreg = LogisticRegressionCV(cv=RepeatedStratifiedKFold(n_splits=10, random_state=7), 
                             max_iter=1000, n_jobs=-1, verbose=3, refit=True, random_state=7).fit(df_cf_x_train, 
                                                                                                  df_cf_y_train)
logreg.score(df_cf_x_test, df_cf_y_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.3s finished
# 0.74

# %% [markdown]
# ##### KNeighborsClassifier

# %%
knn = RandomizedSearchCV(estimator=KNeighborsClassifier(), param_distributions={'n_neighbors':range(10, 16), 
                                                                'weights':['uniform', 'distance'], 
                                                                'n_jobs':[-1]}, 
                  cv=RepeatedStratifiedKFold(random_state=7), n_jobs=-1, return_train_score=True, 
                         verbose=3, refit=True, n_iter=100)
knn.fit(df_cf_x_train, df_cf_y_train)
knn.best_params_
# Out:
# Fitting 50 folds for each of 12 candidates, totalling 600 fits
# {'weights': 'distance', 'n_neighbors': 15, 'n_jobs': -1}

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(10, 16), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'distance'],
        label='Distance Weight', c='red')
plt.plot(range(10, 16), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'uniform'], 
        label='Uniform Weight', c='black')
plt.title(f"KNeighborsClassifier -> {knn.score(df_cf_x_test, df_cf_y_test)}")
plt.xlabel('N Neighbors')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Naive-Bayes Classifier

# %%
gnb = GaussianNB().partial_fit(df_cf_x_train, df_cf_y_train, np.unique(df_cf_y_train))
gnb.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.75

# %% [markdown]
# ##### Decision Tree Classifier (for fun, not to be used for actual predictions, instead just to have a quick look at the decision tree)

# %%
dtc = DecisionTreeClassifier(criterion='entropy').fit(df_cf_x_train, df_cf_y_train)
dtc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.56

# %%
fig = plt.figure(figsize=(12, 8))
dtc_tree = tree.plot_tree(dtc, feature_names=df_cf.columns, class_names=['Pass', 'Fail'], filled=True, rounded=True,
                         fontsize=3)

# %% [markdown]
# ##### Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(n_estimators=100, max_depth=6, random_state=7, verbose=3, warm_start=True,
                                n_iter_no_change=30).fit(df_cf_x_train, df_cf_y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2802            0.40s
#          2           1.2030            0.39s
#          3           1.1357            0.36s
#          4           1.0754            0.34s
#          5           1.0174            0.34s
#          6           0.9636            0.34s
#          7           0.9158            0.35s
#          8           0.8730            0.35s
#          9           0.8386            0.33s
#         10           0.8005            0.33s
#         11           0.7669            0.33s
#         12           0.7359            0.32s
#         13           0.7090            0.33s
#         14           0.6830            0.32s
#         15           0.6610            0.32s
#         16           0.6383            0.32s
#         17           0.6158            0.31s
#         18           0.5968            0.31s
#         19           0.5801            0.31s
#         20           0.5562            0.30s
#         21           0.5389            0.30s
#         22           0.5263            0.29s
#         23           0.5090            0.29s
#         24           0.4930            0.29s
#         25           0.4787            0.28s
#         26           0.4639            0.27s
#         27           0.4505            0.27s
#         28           0.4395            0.26s
#         29           0.4282            0.26s
#         30           0.4139            0.25s
#         31           0.4006            0.25s
#         32           0.3912            0.24s
#         33           0.3829            0.24s
#         34           0.3750            0.23s
#         35           0.3648            0.23s
#         36           0.3556            0.23s
#         37           0.3458            0.22s
#         38           0.3352            0.22s
#         39           0.3285            0.22s
#         40           0.3225            0.21s
#         41           0.3136            0.21s
#         42           0.3057            0.20s
#         43           0.2968            0.20s
#         44           0.2882            0.20s

# %%
gbc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.64

# %% [markdown]
# ####  Evaluating models

# %%
models = pd.DataFrame(index=['RandomForestClassifier', 'LogisticRegressionCV', 'KNeighborsClassifier', 
                      'GaussianNB', 'GradientBoosting'])
models.index.name="Algorithms"
models['Score'] = np.round([rfc.score(df_cf_x_test, df_cf_y_test), logreg.score(df_cf_x_test, df_cf_y_test), 
                  knn.score(df_cf_x_test, df_cf_y_test), gnb.score(df_cf_x_test, df_cf_y_test), 
                  gbc.score(df_cf_x_test, df_cf_y_test)], 4) * 100
models['f1 Score'] = np.round([f1_score(df_cf_y_test, rfc.predict(df_cf_x_test)), 
                      f1_score(df_cf_y_test, logreg.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, knn.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gnb.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gbc.predict(df_cf_x_test))], 4) * 100
models['Used Model'] = [rfc, logreg, knn, gnb, gbc]
models = models.sort_values(["Score", 'f1 Score'], ascending=False)
models
# Out:
#                         Score  f1 Score  \
# Algorithms
# GaussianNB               75.0     73.12
# LogisticRegressionCV     74.0     71.11
# RandomForestClassifier   69.0     65.17
# KNeighborsClassifier     67.0     61.18
# GradientBoosting         64.0     60.00
#
#                                                                Used Model
# Algorithms
# GaussianNB                                                   GaussianNB()
# LogisticRegressionCV    LogisticRegressionCV(cv=RepeatedStratifiedKFol...
# RandomForestClassifier  RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# KNeighborsClassifier    RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# GradientBoosting        ([DecisionTreeRegressor(criterion='friedman_ms...

# %%
models_list = [rfc, logreg, knn, gnb, gbc]
model_names = ['RandomForestClassifier', 'LogisticRegressionCV', 'KNearestNeighbors', 
               'GaussianNB', 'GradientBoosting']
fig = plt.figure(constrained_layout=True, figsize=(12, 8))
grid = gs(nrows=1, ncols=len(models), figure=fig)
for _ in range(len(models)):
    ax = fig.add_subplot(grid[_])
    plt.rcParams.update({'font.size':13})
    plot_confusion_matrix(models_list[_], df_cf_x_test, df_cf_y_test, labels=[0, 1],
                         display_labels=['Fail', 'Pass'], colorbar=False, ax=ax, cmap='afmhot')
    plt.title(f"{model_names[_]}", fontsize=13)
    
plt.show()

# %% [markdown]
# ### Example

# %%
Lab_1 = 7
Lab_2 = 6
Lab_3 = 6
Lab_4 = 4
Lab_5 = 6
Lab_6 = 8
Lab_7 = 5
Lab_8 = 3

Asgn_1 = 6
Asgn_2 = 4
Asgn_3 = 4
Asgn_4 = 5

MT_1 = 45
MT_2 = 65

test = [Lab_1, Lab_2, Lab_3, Lab_4, Lab_5, Lab_6, Lab_7, Lab_8,
       Asgn_1, Asgn_2, Asgn_3, Asgn_4,
       MT_1, MT_2]

# %%
def calculate(test):
    test = scaler.transform(np.array(test).reshape(1, -1)) # scaling scores 
    
    test_ = [0] * len(test[0]) # making dummy list to cummulatively add each test score
    probabs = [] # to store each probability as each test score gets entered
    for x in range(len(test[0])):
        test_[x] = test[0][x]
        probabs.append(models.iloc[0]['Used Model'].predict_proba(np.array([test_]))[0][1] * 100)
    
    pf = None
    if models.iloc[0]['Used Model'].predict(test) == 0:
        pf = 'Fail'
    else:
        pf = 'Pass'
        
    plt.figure(figsize=(8,7))
    plt.title(f"Probability of passing after each test taken\nPredicted Pass or Fail? -> {pf}\
    \nChance of passing -> {models.iloc[0]['Used Model'].predict_proba(test)[0][1] * 100:.2f}%")
    plt.plot(['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4', 'Lab 5', 'Lab 6', 'Lab 7', 'Lab 8',
             'Asgn 1', 'Asgn 2', 'Asgn 3', 'Asgn 4',
             'MT 1', 'MT 2'], probabs, c='black', linestyle='--')
    plt.axhline(50, color='red')
    plt.xticks(rotation=45)
    plt.ylabel('Probability (%)')
    plt.margins(0.02, 0.02)
    plt.tight_layout()
    plt.show()
    
    return 'Thank you for using this program!'
calculate(test)
# Out:
# 'Thank you for using this program!'

# %% [markdown]
# ### Experimenting Neural Network

# %%
def neural_model():
    neural_model = Sequential([Dense(14, input_dim=14), Activation('relu'),
                   Dense(64), Activation('relu'),
                   Dense(32), Activation('relu'),
                   Dense(1), Activation('sigmoid')])
    neural_model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
    return neural_model

early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=10, 
                                                  mode='max', restore_best_weights=True)

scikit_neural = KerasClassifier(build_fn=neural_model)
scikit_neural.fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=1, 
                                  use_multiprocessing=True, validation_data=(df_cf_x_test, df_cf_y_test), 
                                  callbacks=early_stopping)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6730 - accuracy: 0.6277 - val_loss: 0.6586 - val_accuracy: 0.5800
# Epoch 2/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6543 - accuracy: 0.6169 - val_loss: 0.6473 - val_accuracy: 0.5800
# Epoch 3/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6595 - val_loss: 0.6336 - val_accuracy: 0.6000
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6180 - accuracy: 0.6727 - val_loss: 0.6214 - val_accuracy: 0.6200
# Epoch 5/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5974 - accuracy: 0.7005 - val_loss: 0.6034 - val_accuracy: 0.6300
# Epoch 6/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6980 - val_loss: 0.5977 - val_accuracy: 0.6700
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5809 - accuracy: 0.7105 - val_loss: 0.5845 - val_accuracy: 0.6900
# Epoch 8/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5531 - accuracy: 0.7093 - val_loss: 0.5794 - val_accuracy: 0.7100
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5647 - accuracy: 0.6993 - val_loss: 0.5741 - val_accuracy: 0.7000
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5395 - accuracy: 0.7322 - val_loss: 0.5845 - val_accuracy: 0.7000
# Epoch 11/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5305 - accuracy: 0.7452 - val_loss: 0.5861 - val_accuracy: 0.7100
# Epoch 12/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5468 - accuracy: 0.7253 - val_loss: 0.5898 - val_accuracy: 0.7200
# Epoch 13/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5369 - accuracy: 0.7211 - val_loss: 0.5923 - val_accuracy: 0.6900
# Epoch 14/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7337 - val_loss: 0.5894 - val_accuracy: 0.6900
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5180 - accuracy: 0.7467 - val_loss: 0.5876 - val_accuracy: 0.7200
# Epoch 16/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5165 - accuracy: 0.7502 - val_loss: 0.5855 - val_accuracy: 0.7100
# Epoch 17/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7869 - val_loss: 0.5890 - val_accuracy: 0.6900
# Epoch 18/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4962 - accuracy: 0.7607 - val_loss: 0.5883 - val_accuracy: 0.6900
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.7610 - val_loss: 0.5762 - val_accuracy: 0.7100
# Epoch 20/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4918 - accuracy: 0.7564 - val_loss: 0.5857 - val_accuracy: 0.6700
# Epoch 21/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7581 - val_loss: 0.5916 - val_accuracy: 0.6800
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5037 - accuracy: 0.7484 - val_loss: 0.5777 - val_accuracy: 0.7200
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping

# %%
print("f1_score =", f1_score(df_cf_y_test, scikit_neural.predict(df_cf_x_test)))
print("Accuracy =", scikit_neural.score(df_cf_x_test, df_cf_y_test))
# Out:
# f1_score = 0.6888888888888889
# 4/4 [==============================] - 0s 996us/step - loss: 0.5898 - accuracy: 0.7200
# Accuracy = 0.7200000286102295

# %%
print(f"Neural Network probability of passing ->\
 {scikit_neural.predict_proba(scaler.transform(np.array(test).reshape(1, -1)))[0][1]*100:.2f}%")
# Out:
# Neural Network probability of passing -> 25.29%

# %%
neural_model().summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 14)                210
# _________________________________________________________________
# activation_16 (Activation)   (None, 14)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                960
# _________________________________________________________________
# activation_17 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# activation_18 (Activation)   (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 33
# _________________________________________________________________
# activation_19 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 3,283
# Trainable params: 3,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
pd.DataFrame(neural_model().fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=0,
                       validation_data=(df_cf_x_test, df_cf_y_test), callbacks=early_stopping).history).plot()
plt.show()
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping

# %%
_ = metric.FalseNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('False Negatives =', _.result().numpy())

_ = metric.TrueNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('True Negatives =', _.result().numpy())
# Out:
# False Negatives = 14.0
# True Negatives = 41.0
