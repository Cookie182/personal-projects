# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec as gs
# %matplotlib inline
plt.style.use('bmh')
from scipy import stats as ss
import seaborn as sns
sns.set_style('dark')
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, RandomizedSearchCV
from sklearn.metrics import f1_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# the big boy stuff
import tensorflow.keras.metrics as metric
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.wrappers.scikit_learn import KerasClassifier

# %%
n = 500 # number of students
def grades(lower, upper, mean, std, n=n): # get an array of grades in a range and distribution parameters
    return [int(x) for x in (ss.truncnorm.rvs(((lower - mean) / std), ((upper - mean) / std), loc=mean, scale=std, size=n))]

# %% [markdown]
# ### Gathering grades
# #### Labs

# %%
Lab = dict()
for _ in range(1, 9):
    Lab[_] = grades(0, 10, 7, 3)
for key, item in Lab.items():
    print(f"Lab {key} -> {item[:10]}")
# Out:
# Lab 1 -> [4, 7, 6, 6, 3, 6, 7, 4, 7, 4]
# Lab 2 -> [9, 4, 7, 7, 5, 7, 1, 6, 5, 9]
# Lab 3 -> [8, 7, 6, 8, 5, 3, 6, 3, 7, 6]
# Lab 4 -> [4, 5, 7, 7, 2, 3, 3, 8, 5, 7]
# Lab 5 -> [6, 6, 9, 7, 9, 8, 7, 4, 5, 6]
# Lab 6 -> [7, 5, 4, 7, 7, 6, 9, 9, 7, 8]
# Lab 7 -> [2, 2, 5, 9, 9, 5, 4, 9, 8, 5]
# Lab 8 -> [3, 8, 4, 6, 5, 7, 4, 3, 7, 7]

# %%
fig = plt.figure(constrained_layout=True, figsize=(12, 9))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(8):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Lab[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=10)
    ax.set_title(f"Lab {_+1}")
fig.suptitle('Grades for Labs', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Assignments

# %%
Assignment = dict()
for _ in range(1, 5):
    Assignment[_] = grades(0, 10, 7, 3)
for key, item in Assignment.items():
    print(f"Assignment {key} -> {item[:10]}")
# Out:
# Assignment 1 -> [6, 5, 7, 4, 5, 4, 9, 5, 6, 5]
# Assignment 2 -> [9, 8, 5, 0, 6, 1, 9, 9, 6, 9]
# Assignment 3 -> [6, 6, 8, 9, 7, 4, 5, 9, 9, 1]
# Assignment 4 -> [8, 7, 4, 2, 5, 9, 4, 7, 5, 4]

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 14))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(4):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Assignment[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=10)
    ax.set_title(f"Assignment {_+1}")
fig.suptitle('Grades for Assignments', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Mid-Terms

# %%
Mid_term = dict()
for _ in range(1, 3):
    Mid_term[_] = grades(0, 100, 75, 20)
for key, item in Mid_term.items():
    print(f"Mid-Term {key} -> {item[:10]}")
# Out:
# Mid-Term 1 -> [39, 77, 74, 77, 92, 79, 82, 96, 69, 69]
# Mid-Term 2 -> [80, 64, 35, 92, 72, 90, 59, 45, 69, 61]

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 6))
grid = gs(nrows=1, ncols=2, figure=fig)
for _ in range(2):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Mid_term[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=25)
    ax.set_title(f"Mid-Term {_+1}")
fig.suptitle('Grades for Mid-Terms', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Final Exam

# %%
Final = grades(0, 100, 65, 25)
print(f"Final Exam -> {Final[:10]}")
# Out:
# Final Exam -> [87, 98, 69, 30, 55, 81, 93, 68, 63, 18]

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Final, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=35)
plt.show()

# %% [markdown]
# ### Grade Weights
# Each type of test will contribute this much to the final grade:
# * Final Exam = 30%
# * Mid-Terms = 30%
# * Assignments = 20%
# * Labs = 20%
#
# Total passing percentage is assumed to be **60%**

# %% [markdown]
# ### Making the DataFrame
# #### Combining the marks togethe

# %%
df = pd.DataFrame(index=range(1, n+1))
df.index.name = 'Student'

# automate the process of inputting the grades for all tests for each student
for _ in range(1, 9):
    df[f"Lab {_}"] = Lab[_]

for _ in range(1, 5):
    df[f"Assignment {_}"] = Assignment[_]
    
for _ in range(1, 3):
    df[f"Mid-Term {_}"] = Mid_term[_]
    
df['Final'] = Final
    
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            4      9      8      4      6      7      2      3             6
# 2            7      4      7      5      6      5      2      8             5
# 3            6      7      6      7      9      4      5      4             7
# 4            6      7      8      7      7      7      9      6             4
# 5            3      5      5      2      9      7      9      5             5
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   9             6             8          39          80
# 2                   8             6             7          77          64
# 3                   5             8             4          74          35
# 4                   0             9             2          77          92
# 5                   6             7             5          92          72
#
#          Final
# Student
# 1           87
# 2           98
# 3           69
# 4           30
# 5           55

# %%
print(f"No. of students -> {len(df)}\nNumber of tests -> {df.shape[1]}")
# Out:
# No. of students -> 500
# Number of tests -> 15

# %% [markdown]
# #### Determining if a student passes

# %%
Final_percent = 0.3
Mid_term_percent = 0.3
Assignments_percent = 0.2
Labs_percent = 0.2

# %% [markdown]
# Calculate the total grade for each category of test, then use that total and calculate the overall percentage of how much it contributes to students (based on the test's weightage) **overall** grade

# %%
lab_grades = list(df.iloc[:, :8].apply(lambda x: np.sum(x) / 80, axis=1) * Labs_percent)
assignment_grades = list(df.iloc[:, 8:12].apply(lambda x: np.sum(x) / 40, axis=1) * Assignments_percent)
mid_term_grades = list(df.iloc[:, 12:14].apply(lambda x: np.sum(x) / 200, axis=1) * Mid_term_percent)
final_grades = list(df.Final.apply(lambda x: (x / 100) * Final_percent))
lab_grades[:10]
# Out:
# [0.1075,
#  0.11000000000000001,
#  0.12,
#  0.14250000000000002,
#  0.1125,
#  0.1125,
#  0.1025,
#  0.11499999999999999,
#  0.1275,
#  0.13]

# %%
overall_grades = [] # calculate the total grade percentage
for _ in range(n):
    overall_grades.append(np.round((lab_grades[_] + assignment_grades[_] + mid_term_grades[_] + final_grades[_]) * 100, 2))
overall_grades[:10]
# Out:
# [69.2, 74.55, 61.05, 56.1, 63.85, 69.9, 72.8, 68.05, 65.35, 47.4]

# %% [markdown]
# #### Finishing the final table

# %%
df['Total'] = overall_grades
df['Pass/Fail'] = ["Pass" if x > 60 else "Fail" for x in overall_grades]
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            4      9      8      4      6      7      2      3             6
# 2            7      4      7      5      6      5      2      8             5
# 3            6      7      6      7      9      4      5      4             7
# 4            6      7      8      7      7      7      9      6             4
# 5            3      5      5      2      9      7      9      5             5
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   9             6             8          39          80
# 2                   8             6             7          77          64
# 3                   5             8             4          74          35
# 4                   0             9             2          77          92
# 5                   6             7             5          92          72
#
#          Final  Total Pass/Fail
# Student
# 1           87  69.20      Pass
# 2           98  74.55      Pass
# 3           69  61.05      Pass
# 4           30  56.10      Fail
# 5           55  63.85      Pass

# %%
print(f"Students failed -> {len(df[df['Pass/Fail'] == 'Fail'])}\nStudents passed -> {len(df[df['Pass/Fail'] == 'Pass'])}")
# Out:
# Students failed -> 173
# Students passed -> 327

# %%
df.describe().drop(['count', '25%', '50%', '75%'])
# Out:
#          Lab 1     Lab 2     Lab 3     Lab 4     Lab 5     Lab 6     Lab 7  \
# mean  5.672000  5.762000  5.760000  5.744000  5.792000  5.770000  5.718000
# std   2.287987  2.272374  2.244209  2.194561  2.338305  2.262596  2.273503
# min   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# max   9.000000  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000
#
#          Lab 8  Assignment 1  Assignment 2  Assignment 3  Assignment 4  \
# mean  5.506000      5.786000       5.82800      5.570000      5.716000
# std   2.185295      2.237458       2.30761      2.276723      2.248879
# min   0.000000      0.000000       0.00000      0.000000      0.000000
# max   9.000000      9.000000       9.00000      9.000000      9.000000
#
#       Mid-Term 1  Mid-Term 2      Final      Total
# mean   70.824000   69.878000  62.822000  62.832900
# std    16.617621   16.305424  20.649337   7.703783
# min    23.000000   11.000000   0.000000  39.250000
# max    99.000000   99.000000  99.000000  80.600000

# %% [markdown]
# ### Creating excel file

# %%
df.to_excel("Grades.xlsx", sheet_name='Grades')

# %% [markdown]
# ### Making the Classifier
# #### Preprocessing

# %%
df_cf = df.copy()
df_cf.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            4      9      8      4      6      7      2      3             6
# 2            7      4      7      5      6      5      2      8             5
# 3            6      7      6      7      9      4      5      4             7
# 4            6      7      8      7      7      7      9      6             4
# 5            3      5      5      2      9      7      9      5             5
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term 1  Mid-Term 2  \
# Student
# 1                   9             6             8          39          80
# 2                   8             6             7          77          64
# 3                   5             8             4          74          35
# 4                   0             9             2          77          92
# 5                   6             7             5          92          72
#
#          Final  Total Pass/Fail
# Student
# 1           87  69.20      Pass
# 2           98  74.55      Pass
# 3           69  61.05      Pass
# 4           30  56.10      Fail
# 5           55  63.85      Pass

# %%
df_cf_y = LabelEncoder().fit_transform(df_cf['Pass/Fail'])
df_cf.drop(['Final', 'Total', 'Pass/Fail'], axis=1, inplace=True)
scaler = StandardScaler().fit(df_cf)
df_cf_x = scaler.transform(df_cf)
df_cf_x[0]
# Out:
# array([-0.73150517,  1.42636861,  0.99912424, -0.795488  ,  0.0890424 ,
#         0.54416789, -1.637     , -1.14790431,  0.09574006,  1.37595872,
#         0.18905711,  1.01663404, -1.91699357,  0.62139674])

# %%
df_cf_x_train, df_cf_x_test, df_cf_y_train, df_cf_y_test = train_test_split(df_cf_x, df_cf_y, stratify=df_cf_y, 
                                                                           test_size=.15, random_state=7)
print(f"Train X -> {df_cf_x_train.shape}\nTrain y -> {df_cf_y_train.shape}")
print(f"Test X -> {df_cf_x_test.shape}\nTest y -> {df_cf_y_test.shape}")
# Out:
# Train X -> (425, 14)
# Train y -> (425,)
# Test X -> (75, 14)
# Test y -> (75,)

# %% [markdown]
# #### Setting up the models
# ##### RandomForestClassifier

# %%
rfc = RandomizedSearchCV(estimator=RandomForestClassifier(),
                  param_distributions={'n_estimators':range(100, 1050, 100), 
                                       'warm_start':[True], 'criterion':['gini', 'entropy']},
                  n_jobs=-1, cv=RepeatedStratifiedKFold(random_state=7), 
                  return_train_score=True, verbose=3, n_iter=100, refit=True)
rfc.fit(df_cf_x_train, df_cf_y_train)
rfc.best_params_
# Out:
# Fitting 50 folds for each of 20 candidates, totalling 1000 fits
# {'warm_start': True, 'n_estimators': 500, 'criterion': 'entropy'}

# %%
plt.figure(figsize=(12, 7))
plt.title(f"RandomForestClassifier score -> {rfc.score(df_cf_x_test, df_cf_y_test)}")
plt.plot(range(100, 1050, 100), 
         pd.DataFrame(rfc.cv_results_)['mean_test_score'][pd.DataFrame(rfc.cv_results_)['param_criterion'] == 'gini'], 
         label='Gini Test')
plt.plot(range(100, 1050, 100), 
         pd.DataFrame(rfc.cv_results_)['mean_test_score'][pd.DataFrame(rfc.cv_results_)['param_criterion'] == 'entropy'], 
         label='Entropy Test')
plt.xlabel('Estimators')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### LogisticRegressionCV

# %%
logreg = LogisticRegressionCV(cv=RepeatedStratifiedKFold(n_splits=10, random_state=7), 
                             max_iter=1000, n_jobs=-1, verbose=3, refit=True, random_state=7).fit(df_cf_x_train, 
                                                                                                  df_cf_y_train)
logreg.score(df_cf_x_test, df_cf_y_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.4s finished
# 0.7733333333333333

# %% [markdown]
# ##### KNeighborsClassifier

# %%
knn = RandomizedSearchCV(estimator=KNeighborsClassifier(), param_distributions={'n_neighbors':range(1, 16), 
                                                                'weights':['uniform', 'distance'], 
                                                                'n_jobs':[-1]}, 
                  cv=RepeatedStratifiedKFold(random_state=7), n_jobs=-1, return_train_score=True, 
                         verbose=3, refit=True, n_iter=100)
knn.fit(df_cf_x_train, df_cf_y_train)
knn.best_params_
# Out:
# Fitting 50 folds for each of 30 candidates, totalling 1500 fits
# {'weights': 'uniform', 'n_neighbors': 9, 'n_jobs': -1}

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(1, 16), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'distance'],
        label='Distance Weight')
plt.plot(range(1, 16), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'uniform'], 
        label='Uniform Weight')
plt.title(f"KNeighborsClassifier -> {knn.score(df_cf_x_test, df_cf_y_test)}")
plt.xlabel('N Neighbors')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Naive-Bayes Classifier

# %%
gnb = GaussianNB().partial_fit(df_cf_x_train, df_cf_y_train, np.unique(df_cf_y_train))
gnb.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.7733333333333333

# %% [markdown]
# ##### Decision Tree Classifier

# %%
dtc = DecisionTreeClassifier(criterion='entropy').fit(df_cf_x_train, df_cf_y_train)
dtc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.6533333333333333

# %%
fig = plt.figure(figsize=(12, 8))
dtc_tree = tree.plot_tree(dtc, feature_names=df_cf.columns, class_names=['Pass', 'Fail'], filled=True, rounded=True,
                         fontsize=3)

# %% [markdown]
# ##### Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(n_estimators=1000, max_depth=4, random_state=7, verbose=3, warm_start=True,
                                n_iter_no_change=10).fit(df_cf_x_train, df_cf_y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.2362            1.00s
#          2           1.1923            1.25s
#          3           1.1513            1.50s
#          4           1.1187            1.37s
#          5           1.0888            1.60s
#          6           1.0564            1.49s
#          7           1.0310            1.56s
#          8           1.0049            1.49s
#          9           0.9747            1.43s
#         10           0.9460            1.49s
#         11           0.9234            1.53s
#         12           0.8985            1.48s
#         13           0.8809            1.52s
#         14           0.8620            1.48s
#         15           0.8324            1.51s
#         16           0.8166            1.54s
#         17           0.8054            1.56s
#         18           0.7869            1.53s
#         19           0.7651            1.55s
#         20           0.7462            1.52s
#         21           0.7262            1.54s
#         22           0.7119            1.51s
#         23           0.7009            1.53s

# %%
gbc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.7466666666666667

# %% [markdown]
# ####  Evaluating models

# %%
models = pd.DataFrame(index=['RandomForestClassifier', 'LogisticRegressionCV', 'KNeighborsClassifier', 
                      'GaussianNB', 'DecisionTreeClassifier', 'GradientBoosting'])
models.index.name="Algorithms"
models['Score'] = np.round([rfc.score(df_cf_x_test, df_cf_y_test), logreg.score(df_cf_x_test, df_cf_y_test), 
                  knn.score(df_cf_x_test, df_cf_y_test), gnb.score(df_cf_x_test, df_cf_y_test), 
                  dtc.score(df_cf_x_test, df_cf_y_test), gbc.score(df_cf_x_test, df_cf_y_test)], 4) * 100
models['f1 Score'] = np.round([f1_score(df_cf_y_test, rfc.predict(df_cf_x_test)), 
                      f1_score(df_cf_y_test, logreg.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, knn.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gnb.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, dtc.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gbc.predict(df_cf_x_test))], 4) * 100
models['Used Model'] = [rfc, logreg, knn, gnb, dtc, gbc]
models = models.sort_values(["Score", 'f1 Score'], ascending=False)
models
# Out:
#                         Score  f1 Score  \
# Algorithms
# LogisticRegressionCV    77.33     84.68
# GaussianNB              77.33     84.40
# GradientBoosting        74.67     83.19
# RandomForestClassifier  72.00     81.74
# KNeighborsClassifier    72.00     81.74
# DecisionTreeClassifier  65.33     74.00
#
#                                                                Used Model
# Algorithms
# LogisticRegressionCV    LogisticRegressionCV(cv=RepeatedStratifiedKFol...
# GaussianNB                                                   GaussianNB()
# GradientBoosting        ([DecisionTreeRegressor(criterion='friedman_ms...
# RandomForestClassifier  RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# KNeighborsClassifier    RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# DecisionTreeClassifier        DecisionTreeClassifier(criterion='entropy')

# %%
models_list = [rfc, logreg, knn, gnb, dtc, gbc]
model_names = ['RandomForestClassifier', 'LogisticRegressionCV', 'KNearestNeighbors', 'GaussianNB', 
              'DecisionTreeClassifier', 'GradientBoosting']
fig = plt.figure(constrained_layout=True, figsize=(12, 8))
grid = gs(nrows=1, ncols=len(models), figure=fig)
for _ in range(len(models)):
    ax = fig.add_subplot(grid[_])
    plot_confusion_matrix(models_list[_], df_cf_x_test, df_cf_y_test, labels=[0, 1],
                         display_labels=['Fail', 'Pass'], colorbar=False, ax=ax, cmap='binary')
    plt.title(f"{model_names[_]}", fontsize=13)
    
plt.show()

# %% [markdown]
# ### Example

# %%
Lab_1 = 7
Lab_2 = 6
Lab_3 = 6
Lab_4 = 4
Lab_5 = 6
Lab_6 = 8
Lab_7 = 5
Lab_8 = 3

Asgn_1 = 6
Asgn_2 = 4
Asgn_3 = 4
Asgn_4 = 5

MT_1 = 60
MT_2 = 55

test = [Lab_1, Lab_2, Lab_3, Lab_4, Lab_5, Lab_6, Lab_7, Lab_8,
       Asgn_1, Asgn_2, Asgn_3, Asgn_4,
       MT_1, MT_2]

# %%
def calculate(test):
    test = scaler.transform(np.array(test).reshape(1, -1)) # scaling scores 
    
    test_ = [0] * len(test[0]) # making dummy list to cummulatively add each test score
    probabs = [] # to store each probability as each test score gets entered
    for x in range(len(test[0])):
        test_[x] = test[0][x]
        probabs.append(models.iloc[0]['Used Model'].predict_proba(np.array([test_]))[0][1] * 100)
    
    pf = None
    if models.iloc[0]['Used Model'].predict(test) == 0:
        pf = 'Fail'
    else:
        pf = 'Pass'
        
    plt.figure(figsize=(6,5))
    plt.title(f"Probability of passing after each test taken\nPredicted Pass or Fail? -> {pf}\
    \nChance of passing -> {models.iloc[0]['Used Model'].predict_proba(test)[0][1] * 100:.2f}%")
    plt.plot(['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4', 'Lab 5', 'Lab 6', 'Lab 7', 'Lab 8',
             'Asgn 1', 'Asgn 2', 'Asgn 3', 'Asgn 4',
             'MT 1', 'MT 2'], probabs, c='black', linestyle='--')
    plt.axhline(50, color='red')
    plt.xticks(rotation=45)
    plt.ylabel('Probability (%)')
    plt.margins(0.02, 0.02)
    plt.tight_layout()
    plt.show()
    
    return 'Thank you for using this program!'
calculate(test)
# Out:
# 'Thank you for using this program!'

# %% [markdown]
# ### Experimenting Neural Network

# %%
def neural_classifier():
    model = Sequential([Dense(32, input_dim=14), Activation('relu'),
                        Dense(16), Activation('relu'),
                       Dense(1), Activation('sigmoid')])
    model.compile('adam', 'binary_crossentropy', metrics=[metric.BinaryAccuracy()])
    return model

# %%
nn_clf = KerasClassifier(build_fn=neural_classifier, epochs=20, batch_size=70, verbose=1)
nn_clf.fit(df_cf_x_train, df_cf_y_train, shuffle=False, validation_data=(df_cf_x_test, df_cf_y_test))
# Out:
# Epoch 1/20
# 7/7 [==============================] - 1s 50ms/step - loss: 0.7066 - binary_accuracy: 0.5976 - val_loss: 0.6957 - val_binary_accuracy: 0.5867
# Epoch 2/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6801 - binary_accuracy: 0.6370 - val_loss: 0.6770 - val_binary_accuracy: 0.6400
# Epoch 3/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6619 - binary_accuracy: 0.6667 - val_loss: 0.6605 - val_binary_accuracy: 0.6667
# Epoch 4/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6470 - binary_accuracy: 0.6694 - val_loss: 0.6464 - val_binary_accuracy: 0.6667
# Epoch 5/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6342 - binary_accuracy: 0.6696 - val_loss: 0.6338 - val_binary_accuracy: 0.6533
# Epoch 6/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6231 - binary_accuracy: 0.6768 - val_loss: 0.6223 - val_binary_accuracy: 0.6800
# Epoch 7/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6132 - binary_accuracy: 0.6853 - val_loss: 0.6121 - val_binary_accuracy: 0.6667
# Epoch 8/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6041 - binary_accuracy: 0.6916 - val_loss: 0.6028 - val_binary_accuracy: 0.6667
# Epoch 9/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5958 - binary_accuracy: 0.6939 - val_loss: 0.5943 - val_binary_accuracy: 0.6933
# Epoch 10/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5880 - binary_accuracy: 0.6923 - val_loss: 0.5868 - val_binary_accuracy: 0.6933
# Epoch 11/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5807 - binary_accuracy: 0.6987 - val_loss: 0.5793 - val_binary_accuracy: 0.6933
# Epoch 12/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5737 - binary_accuracy: 0.7044 - val_loss: 0.5720 - val_binary_accuracy: 0.6933
# Epoch 13/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5669 - binary_accuracy: 0.7071 - val_loss: 0.5649 - val_binary_accuracy: 0.6933
# Epoch 14/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5603 - binary_accuracy: 0.7137 - val_loss: 0.5584 - val_binary_accuracy: 0.7067
# Epoch 15/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5542 - binary_accuracy: 0.7306 - val_loss: 0.5521 - val_binary_accuracy: 0.7067
# Epoch 16/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5481 - binary_accuracy: 0.7312 - val_loss: 0.5466 - val_binary_accuracy: 0.7067
# Epoch 17/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5423 - binary_accuracy: 0.7388 - val_loss: 0.5421 - val_binary_accuracy: 0.7067
# Epoch 18/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5369 - binary_accuracy: 0.7357 - val_loss: 0.5382 - val_binary_accuracy: 0.7467
# Epoch 19/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5317 - binary_accuracy: 0.7425 - val_loss: 0.5345 - val_binary_accuracy: 0.7600
# Epoch 20/20
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5266 - binary_accuracy: 0.7473 - val_loss: 0.5311 - val_binary_accuracy: 0.7600

# %%
print(f"Neural Network probability of passing -> \
    {nn_clf.predict_proba(scaler.transform(np.array(test).reshape(1, -1)))[0][1]*100:.2f}%")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# Neural Network probability of passing ->     30.11%

# %%
f1_score(df_cf_y_test, nn_clf.predict(df_cf_x_test))
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 0.8421052631578948

# %%
neural_classifier().summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                480
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
