# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec as gs
# %matplotlib inline
plt.style.use('bmh')
from scipy import stats as ss
import seaborn as sns
sns.set_style('dark')
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, RandomizedSearchCV
from sklearn.metrics import f1_score, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import class_weight

# the big boy stuff
import tensorflow.keras.metrics as metric
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
n = 1000 # number of students
def grades(lower, upper, mean, std, n=n): # get an array of grades in a range and distribution parameters
    return [int(x) for x in (ss.truncnorm.rvs(((lower - mean) / std), ((upper - mean) / std), loc=mean, scale=std, size=n))]

# %% [markdown]
# ### Gathering grades
# #### Labs

# %%
Lab = dict()
for _ in range(1, 9):
    Lab[_] = grades(0, 11, 7, 2)
for key, item in Lab.items():
    print(f"Lab {key} -> {item[:10]}")
# Out:
# Lab 1 -> [9, 7, 8, 6, 7, 7, 7, 4, 3, 4]
# Lab 2 -> [8, 5, 4, 7, 6, 8, 5, 7, 10, 7]
# Lab 3 -> [5, 6, 6, 9, 6, 9, 6, 7, 7, 4]
# Lab 4 -> [5, 7, 4, 7, 6, 7, 7, 5, 6, 10]
# Lab 5 -> [7, 7, 5, 7, 7, 10, 7, 6, 8, 9]
# Lab 6 -> [5, 7, 7, 4, 6, 5, 9, 4, 9, 6]
# Lab 7 -> [4, 7, 6, 9, 7, 6, 4, 6, 9, 7]
# Lab 8 -> [8, 10, 6, 4, 6, 7, 6, 8, 3, 7]

# %%
for _ in range(11):
    print(f"{_} -> {Lab[1].count(_)}")
# Out:
# 0 -> 0
# 1 -> 7
# 2 -> 12
# 3 -> 48
# 4 -> 103
# 5 -> 158
# 6 -> 198
# 7 -> 198
# 8 -> 139
# 9 -> 93
# 10 -> 44

# %%
fig = plt.figure(constrained_layout=True, figsize=(12, 9))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(8):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Lab[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='right', color='blue'), bins=10)
    plt.xticks(range(0, 11))
    ax.set_title(f"Lab {_+1}")
fig.suptitle('Grades for Labs', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Assignments (surprise test)

# %%
Assignment = dict()
for _ in range(1, 5):
    Assignment[_] = grades(0, 21, 12, 4)
for key, item in Assignment.items():
    print(f"Assignment {key} -> {item[:10]}")
# Out:
# Assignment 1 -> [9, 8, 13, 16, 17, 12, 7, 12, 16, 9]
# Assignment 2 -> [20, 14, 10, 7, 5, 14, 6, 12, 15, 4]
# Assignment 3 -> [13, 10, 12, 10, 9, 8, 11, 13, 11, 7]
# Assignment 4 -> [10, 8, 6, 14, 10, 18, 11, 19, 13, 7]

# %%
for _ in range(21):
    print(f"{_} -> {Assignment[1].count(_)}")
# Out:
# 0 -> 3
# 1 -> 3
# 2 -> 6
# 3 -> 11
# 4 -> 13
# 5 -> 29
# 6 -> 29
# 7 -> 61
# 8 -> 74
# 9 -> 92
# 10 -> 88
# 11 -> 86
# 12 -> 113
# 13 -> 90
# 14 -> 82
# 15 -> 79
# 16 -> 62
# 17 -> 34
# 18 -> 27
# 19 -> 13
# 20 -> 5

# %%
fig = plt.figure(constrained_layout=True, figsize=(14, 14))
grid = gs(nrows=4, ncols=2, figure=fig)
for _ in range(4):
    ax = fig.add_subplot(grid[_])
    # comparing distribution of grades to a regular normal distribution line
    sns.distplot(Assignment[(_+1)], fit=ss.norm, ax=ax, norm_hist=True, color='blue', 
                 hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=10)
    ax.set_title(f"Assignment {_+1}")
    plt.xticks(range(0, 21))
fig.suptitle('Grades for Assignments', fontsize=20)
plt.margins(0.001, 0.001)
grid.tight_layout(fig)
plt.show()

# %% [markdown]
# #### Mid-Terms

# %%
Mid_term = grades(0, 51, 30, 15)
print(f"Mid-Term -> {Mid_term[:10]}")
# Out:
# Mid-Term -> [35, 23, 45, 33, 24, 30, 34, 32, 23, 30]

# %%
for _ in range(0, 41, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Mid_term.count(__)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 73
# 10-20 -> 197
# 20-30 -> 327
# 30-40 -> 302
# 40-50 -> 194

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Mid_term, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
plt.title('Mid-Term', fontsize=14)
plt.show()

# %% [markdown]
# #### Project

# %%
Project = grades(0, 101, 55, 35)
print(f"Project -> {Project[:10]}")
# Out:
# Project -> [77, 89, 76, 44, 95, 15, 61, 2, 33, 47]

# %%
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Project.count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 44
# 10-20 -> 88
# 20-30 -> 99
# 30-40 -> 88
# 40-50 -> 88
# 50-60 -> 154
# 60-70 -> 176
# 70-80 -> 88
# 80-90 -> 99
# 90-100 -> 66

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Project, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
plt.title('Project', fontsize=14)
plt.show()

# %% [markdown]
# #### Final Exam

# %%
Final = grades(0, 101, 65, 30)
print(f"Final Exam -> {Final[:10]}")
# Out:
# Final Exam -> [66, 72, 16, 83, 96, 95, 55, 74, 52, 91]

# %%
for _ in range(0, 100, 10):
    c = 0
    for __ in range(_,( _ + 11)):
        c += Final.count(_)
    print(f"{_}-{_+10} -> {c}")
# Out:
# 0-10 -> 22
# 10-20 -> 33
# 20-30 -> 22
# 30-40 -> 121
# 40-50 -> 143
# 50-60 -> 187
# 60-70 -> 132
# 70-80 -> 187
# 80-90 -> 121
# 90-100 -> 176

# %%
plt.figure(figsize=(10, 7))
sns.distplot(Final, fit=ss.norm, norm_hist=True, color='blue', 
             hist_kws=dict(edgecolor='black', align='left', color='blue'), bins=50)
plt.title('Final Exam', fontsize=14)
plt.show()

# %% [markdown]
# ### Grade Weights
# Each type of test will contribute this much to the final grade:
# * Final Exam = 20%
# * Mid-Terms = 10%
# * Assignments = 10%
# * Labs = 20%
# * Project = 40%
#
# Total passing percentage is assumed to be **60%**

# %% [markdown]
# ### Making the DataFrame
# #### Combining the marks togethe

# %%
df = pd.DataFrame(index=range(1, n+1))
df.index.name = 'Student'

# automate the process of inputting the grades for all tests for each student
for _ in range(1, 9):
    df[f"Lab {_}"] = Lab[_]

for _ in range(1, 5):
    df[f"Assignment {_}"] = Assignment[_]
    
df['Mid-Term'] = Mid_term
    
df['Project'] = Project
    
df['Final'] = Final
    
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            9      8      5      5      7      5      4      8             9
# 2            7      5      6      7      7      7      7     10             8
# 3            8      4      6      4      5      7      6      6            13
# 4            6      7      9      7      7      4      9      4            16
# 5            7      6      6      6      7      6      7      6            17
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term  Project  Final
# Student
# 1                  20            13            10        35       77     66
# 2                  14            10             8        23       89     72
# 3                  10            12             6        45       76     16
# 4                   7            10            14        33       44     83
# 5                   5             9            10        24       95     96

# %%
print(f"No. of students -> {len(df)}\nNumber of tests -> {df.shape[1]}")
# Out:
# No. of students -> 1000
# Number of tests -> 15

# %% [markdown]
# #### Determining if a student passes

# %%
Final_percent = 0.2
Mid_term_percent = 0.1
Assignments_percent = 0.1
Labs_percent = 0.2
Project_percent  = 0.4

# %% [markdown]
# Calculate the total grade for each category of test, then use that total and calculate the overall percentage of how much it contributes to students (based on the test's weightage) **overall** grade

# %%
lab_grades = list(df.iloc[:, :8].apply(lambda x: np.sum(x) / 80, axis=1) * Labs_percent)
assignment_grades = list(df.iloc[:, 8:12].apply(lambda x: np.sum(x) / 80, axis=1) * Assignments_percent)
mid_term_grades = list(df['Mid-Term'].apply(lambda x: (x / 50)*Mid_term_percent))
project_grades = list(df.Project.apply(lambda x: (x / 100) * Project_percent))
final_grades = list(df.Final.apply(lambda x: (x / 100) * Final_percent))

# %%
print(f"Lab -> {lab_grades[0]}\nAsgn -> {assignment_grades[0]}\nMid-Term -> {mid_term_grades[0]}\n\
Project -> {project_grades[0]}\nFinal -> {final_grades[0]}")
# Out:
# Lab -> 0.1275
# Asgn -> 0.065
# Mid-Term -> 0.06999999999999999
# Project -> 0.30800000000000005
# Final -> 0.132

# %%
overall_grades = [] # calculate the total grade percentage
for _ in range(n):
    overall_grades.append(np.round((lab_grades[_] + assignment_grades[_] + \
                                    mid_term_grades[_] + final_grades[_] + project_grades[_]) * 100, 3))
overall_grades[:10]
# Out:
# [70.25, 73.6, 59.225, 59.925, 79.875, 52.25, 59.325, 40.75, 48.825, 59.875]

# %% [markdown]
# #### Finishing the final table

# %%
df['Total'] = overall_grades
df['Pass/Fail'] = ["Pass" if x >= 60 else "Fail" for x in overall_grades]
df.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            9      8      5      5      7      5      4      8             9
# 2            7      5      6      7      7      7      7     10             8
# 3            8      4      6      4      5      7      6      6            13
# 4            6      7      9      7      7      4      9      4            16
# 5            7      6      6      6      7      6      7      6            17
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term  Project  Final  \
# Student
# 1                  20            13            10        35       77     66
# 2                  14            10             8        23       89     72
# 3                  10            12             6        45       76     16
# 4                   7            10            14        33       44     83
# 5                   5             9            10        24       95     96
#
#           Total Pass/Fail
# Student
# 1        70.250      Pass
# 2        73.600      Pass
# 3        59.225      Fail
# 4        59.925      Fail
# 5        79.875      Pass

# %%
print(f"Students failed -> {len(df[df['Pass/Fail'] == 'Fail'])}\nStudents passed -> {len(df[df['Pass/Fail'] == 'Pass'])}")
# Out:
# Students failed -> 585
# Students passed -> 415

# %%
df.describe().drop(['count', '25%', '50%', '75%'])
# Out:
#           Lab 1      Lab 2      Lab 3     Lab 4      Lab 5     Lab 6  \
# mean   6.340000   6.420000   6.308000   6.50600   6.419000   6.38900
# std    1.884662   1.925437   1.993266   1.92293   1.888652   1.91973
# min    1.000000   0.000000   0.000000   0.00000   1.000000   0.00000
# max   10.000000  10.000000  10.000000  10.00000  10.000000  10.00000
#
#           Lab 7      Lab 8  Assignment 1  Assignment 2  Assignment 3  \
# mean   6.378000   6.442000     11.354000      11.69400     11.266000
# std    1.886976   1.833575      3.748965       3.82871      3.862663
# min    1.000000   1.000000      0.000000       0.00000      0.000000
# max   10.000000  10.000000     20.000000      20.00000     20.000000
#
#       Assignment 4   Mid-Term     Project       Final      Total
# mean     11.270000  28.197000   52.751000   58.993000  57.036900
# std       3.810725  11.561655   24.916256   23.619671  11.258496
# min       0.000000   0.000000    0.000000    0.000000  19.425000
# max      20.000000  50.000000  100.000000  100.000000  84.850000

# %% [markdown]
# ### Creating excel file

# %%
df.to_excel("Grades.xlsx", sheet_name='Grades')

# %% [markdown]
# ### Making the Classifier
# #### Preprocessing

# %%
df_cf = df.copy()
df_cf.head()
# Out:
#          Lab 1  Lab 2  Lab 3  Lab 4  Lab 5  Lab 6  Lab 7  Lab 8  Assignment 1  \
# Student
# 1            9      8      5      5      7      5      4      8             9
# 2            7      5      6      7      7      7      7     10             8
# 3            8      4      6      4      5      7      6      6            13
# 4            6      7      9      7      7      4      9      4            16
# 5            7      6      6      6      7      6      7      6            17
#
#          Assignment 2  Assignment 3  Assignment 4  Mid-Term  Project  Final  \
# Student
# 1                  20            13            10        35       77     66
# 2                  14            10             8        23       89     72
# 3                  10            12             6        45       76     16
# 4                   7            10            14        33       44     83
# 5                   5             9            10        24       95     96
#
#           Total Pass/Fail
# Student
# 1        70.250      Pass
# 2        73.600      Pass
# 3        59.225      Fail
# 4        59.925      Fail
# 5        79.875      Pass

# %%
df_cf_y = LabelEncoder().fit_transform(df_cf['Pass/Fail'])
df_cf.drop(['Final', 'Total', 'Pass/Fail'], axis=1, inplace=True)
scaler = StandardScaler().fit(df_cf)
df_cf_x = scaler.transform(df_cf)
df_cf_x[0]
# Out:
# array([ 1.41209967,  0.82100358, -0.65653783, -0.78357152,  0.30778076,
#        -0.72390118, -1.2608483 ,  0.85013126, -0.62822082,  2.1704844 ,
#         0.44913774, -0.33343671,  0.588705  ,  0.97370702])

# %%
df_cf_x_train, df_cf_x_test, df_cf_y_train, df_cf_y_test = train_test_split(df_cf_x, df_cf_y, stratify=df_cf_y, 
                                                                           test_size=.10, random_state=7)
print(f"Train X -> {df_cf_x_train.shape}\nTrain y -> {df_cf_y_train.shape}")
print(f"Test X -> {df_cf_x_test.shape}\nTest y -> {df_cf_y_test.shape}")
# Out:
# Train X -> (900, 14)
# Train y -> (900,)
# Test X -> (100, 14)
# Test y -> (100,)

# %% [markdown]
# #### Setting up the models
# ##### RandomForestClassifier

# %%
rfc = RandomizedSearchCV(estimator=RandomForestClassifier(),
                  param_distributions={'n_estimators':range(500, 1050, 100), 
                                       'warm_start':[True], 'criterion':['entropy']},
                  n_jobs=-1, cv=RepeatedStratifiedKFold(random_state=7), 
                  return_train_score=True, verbose=3, n_iter=100, refit=True)
rfc.fit(df_cf_x_train, df_cf_y_train)
rfc.best_params_
# Out:
# Fitting 50 folds for each of 6 candidates, totalling 300 fits
# {'warm_start': True, 'n_estimators': 900, 'criterion': 'entropy'}

# %%
plt.figure(figsize=(8, 5))
plt.title(f"RandomForestClassifier score -> {rfc.score(df_cf_x_test, df_cf_y_test)}")
plt.plot(range(500, 1050, 100), 
         pd.DataFrame(rfc.cv_results_)['mean_test_score'][pd.DataFrame(rfc.cv_results_)['param_criterion'] == 'entropy'], 
         label='Entropy Test', c='red')
plt.xlabel('Estimators')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### LogisticRegressionCV

# %%
logreg = LogisticRegressionCV(cv=RepeatedStratifiedKFold(n_splits=10, random_state=7), 
                             max_iter=1000, n_jobs=-1, verbose=3, refit=True, random_state=7).fit(df_cf_x_train, 
                                                                                                  df_cf_y_train)
logreg.score(df_cf_x_test, df_cf_y_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.9s finished
# 0.91

# %% [markdown]
# ##### KNeighborsClassifier

# %%
knn = RandomizedSearchCV(estimator=KNeighborsClassifier(), param_distributions={'n_neighbors':range(45, 65), 
                                                                'weights':['uniform', 'distance'], 
                                                                'n_jobs':[-1]}, 
                  cv=RepeatedStratifiedKFold(random_state=7), n_jobs=-1, return_train_score=True, 
                         verbose=3, refit=True, n_iter=100)
knn.fit(df_cf_x_train, df_cf_y_train)
knn.best_params_
# Out:
# Fitting 50 folds for each of 40 candidates, totalling 2000 fits
# {'weights': 'distance', 'n_neighbors': 59, 'n_jobs': -1}

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(45, 65), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'distance'],
        label='Distance Weight', c='red')
plt.plot(range(45, 65), pd.DataFrame(knn.cv_results_)['mean_test_score'][pd.DataFrame(knn.cv_results_)['param_weights'] == 'uniform'], 
        label='Uniform Weight', c='black')
plt.title(f"KNeighborsClassifier -> {knn.score(df_cf_x_test, df_cf_y_test)}")
plt.xlabel('N Neighbors')
plt.ylabel('Score')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Naive-Bayes Classifier

# %%
gnb = GaussianNB().partial_fit(df_cf_x_train, df_cf_y_train, np.unique(df_cf_y_train))
gnb.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.91

# %% [markdown]
# ##### Decision Tree Classifier (for fun, not to be used for actual predictions, instead just to have a quick look at the decision tree)

# %%
dtc = DecisionTreeClassifier(criterion='entropy').fit(df_cf_x_train, df_cf_y_train)
dtc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.79

# %%
fig = plt.figure(figsize=(12, 8))
dtc_tree = tree.plot_tree(dtc, feature_names=df_cf.columns, class_names=['Pass', 'Fail'], filled=True, rounded=True,
                         fontsize=3)

# %% [markdown]
# ##### Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier(n_estimators=100, max_depth=6, random_state=7, verbose=3, warm_start=True,
                                n_iter_no_change=30).fit(df_cf_x_train, df_cf_y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1986            0.25s
#          2           1.0693            0.32s
#          3           0.9600            0.31s
#          4           0.8614            0.30s
#          5           0.7744            0.29s
#          6           0.6990            0.31s
#          7           0.6361            0.30s
#          8           0.5785            0.29s
#          9           0.5286            0.30s
#         10           0.4865            0.29s
#         11           0.4450            0.30s
#         12           0.4092            0.29s
#         13           0.3755            0.29s
#         14           0.3462            0.29s
#         15           0.3179            0.29s
#         16           0.2935            0.29s
#         17           0.2725            0.29s
#         18           0.2520            0.28s
#         19           0.2349            0.28s
#         20           0.2167            0.27s
#         21           0.2031            0.27s
#         22           0.1897            0.27s
#         23           0.1779            0.27s
#         24           0.1656            0.26s
#         25           0.1552            0.26s
#         26           0.1449            0.25s
#         27           0.1376            0.25s
#         28           0.1291            0.25s
#         29           0.1214            0.24s
#         30           0.1139            0.24s
#         31           0.1075            0.24s
#         32           0.1018            0.23s
#         33           0.0964            0.23s
#         34           0.0912            0.22s
#         35           0.0865            0.22s
#         36           0.0813            0.22s
#         37           0.0777            0.21s
#         38           0.0734            0.21s
#         39           0.0699            0.21s
#         40           0.0664            0.20s
#         41           0.0629            0.20s
#         42           0.0602            0.20s
#         43           0.0571            0.19s
#         44           0.0543            0.19s

# %%
gbc.score(df_cf_x_test, df_cf_y_test)
# Out:
# 0.89

# %% [markdown]
# ####  Evaluating models

# %%
models = pd.DataFrame(index=['RandomForestClassifier', 'LogisticRegressionCV', 'KNeighborsClassifier', 
                      'GaussianNB', 'GradientBoosting'])
models.index.name="Algorithms"
models['Score'] = np.round([rfc.score(df_cf_x_test, df_cf_y_test), logreg.score(df_cf_x_test, df_cf_y_test), 
                  knn.score(df_cf_x_test, df_cf_y_test), gnb.score(df_cf_x_test, df_cf_y_test), 
                  gbc.score(df_cf_x_test, df_cf_y_test)], 4) * 100
models['f1 Score'] = np.round([f1_score(df_cf_y_test, rfc.predict(df_cf_x_test)), 
                      f1_score(df_cf_y_test, logreg.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, knn.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gnb.predict(df_cf_x_test)),
                     f1_score(df_cf_y_test, gbc.predict(df_cf_x_test))], 4) * 100
models['Used Model'] = [rfc, logreg, knn, gnb, gbc]
models = models.sort_values(["Score", 'f1 Score'], ascending=False)
models
# Out:
#                         Score  f1 Score  \
# Algorithms
# LogisticRegressionCV     91.0     88.89
# GaussianNB               91.0     88.61
# RandomForestClassifier   90.0     87.50
# GradientBoosting         89.0     86.42
# KNeighborsClassifier     83.0     75.36
#
#                                                                Used Model
# Algorithms
# LogisticRegressionCV    LogisticRegressionCV(cv=RepeatedStratifiedKFol...
# GaussianNB                                                   GaussianNB()
# RandomForestClassifier  RandomizedSearchCV(cv=RepeatedStratifiedKFold(...
# GradientBoosting        ([DecisionTreeRegressor(criterion='friedman_ms...
# KNeighborsClassifier    RandomizedSearchCV(cv=RepeatedStratifiedKFold(...

# %%
models_list = [rfc, logreg, knn, gnb, gbc]
model_names = ['RandomForestClassifier', 'LogisticRegressionCV', 'KNearestNeighbors', 
               'GaussianNB', 'GradientBoosting']
fig = plt.figure(constrained_layout=True, figsize=(12, 8))
grid = gs(nrows=1, ncols=len(models), figure=fig)
for _ in range(len(models)):
    ax = fig.add_subplot(grid[_])
    plt.rcParams.update({'font.size':13})
    plot_confusion_matrix(models_list[_], df_cf_x_test, df_cf_y_test, labels=[0, 1],
                         display_labels=['Fail', 'Pass'], colorbar=False, ax=ax, cmap='afmhot')
    plt.title(f"{model_names[_]}", fontsize=13)
    
plt.show()

# %% [markdown]
# ### Example

# %%
Lab_1 = 8
Lab_2 = 6
Lab_3 = 6
Lab_4 = 4
Lab_5 = 8
Lab_6 = 7
Lab_7 = 5
Lab_8 = 7

Asgn_1 = 11
Asgn_2 = 12
Asgn_3 = 13
Asgn_4 = 11

MT = 35

Proj = 61

test = [Lab_1, Lab_2, Lab_3, Lab_4, Lab_5, Lab_6, Lab_7, Lab_8,
       Asgn_1, Asgn_2, Asgn_3, Asgn_4,
       MT, Proj]

# %%
def calculate(test):
    test = scaler.transform(np.array(test).reshape(1, -1)) # scaling scores 
    
    test_ = [0] * len(test[0]) # making dummy list to cummulatively add each test score
    probabs = [] # to store each probability as each test score gets entered
    for x in range(len(test[0])):
        test_[x] = test[0][x]
        probabs.append(models.iloc[0]['Used Model'].predict_proba(np.array([test_]))[0][1] * 100)
    print(probabs)
    
    pf = None
    if models.iloc[0]['Used Model'].predict(test) == 0:
        pf = 'Fail'
    else:
        pf = 'Pass'
        
    plt.figure(figsize=(8,7))
    plt.title(f"Probability of passing after each test taken\nPredicted Pass or Fail? -> {pf}\
    \nChance of passing -> {models.iloc[0]['Used Model'].predict_proba(test)[0][1] * 100:.2f}%", fontsize=14)
    plt.plot(['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4', 'Lab 5', 'Lab 6', 'Lab 7', 'Lab 8',
             'Asgn 1', 'Asgn 2', 'Asgn 3', 'Asgn 4',
             'MT 1', 'MT 2'], probabs, c='black', linestyle='--')
    plt.axhline(50, color='red')
    plt.xticks(rotation=45)
    plt.ylabel('Probability (%)')
    plt.margins(0.02, 0.02)
    plt.tight_layout()
    plt.show()
    
    return 'Thank you for using this program!'
calculate(test)
# Out:
# [24.751723400586968, 24.257755888431337, 24.10216834401826, 18.648856116747968, 22.84316596717471, 23.02905830137573, 21.163106595019386, 22.66230290392139, 22.55718337271917, 22.663341958686107, 24.66373919893541, 24.221234361056638, 34.980541540508796, 62.67029770887306]
# 'Thank you for using this program!'

# %% [markdown]
# ### Experimenting Neural Network

# %%
def neural_model():
    neural_model = Sequential([Dense(14, input_dim=14), Activation('relu'),
                   Dense(64), Activation('relu'),
                   Dense(32), Activation('relu'),
                   Dense(1), Activation('sigmoid')])
    neural_model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])
    return neural_model

early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=10, 
                                                  mode='max', restore_best_weights=True)

scikit_neural = KerasClassifier(build_fn=neural_model)
scikit_neural.fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=1, 
                                  use_multiprocessing=True, validation_data=(df_cf_x_test, df_cf_y_test), 
                                  callbacks=early_stopping)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 21ms/step - loss: 0.7115 - accuracy: 0.4565 - val_loss: 0.6453 - val_accuracy: 0.6200
# Epoch 2/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6461 - accuracy: 0.6098 - val_loss: 0.5931 - val_accuracy: 0.7100
# Epoch 3/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.7148 - val_loss: 0.5430 - val_accuracy: 0.7400
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5169 - accuracy: 0.7748 - val_loss: 0.4869 - val_accuracy: 0.8100
# Epoch 5/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4882 - accuracy: 0.7781 - val_loss: 0.4385 - val_accuracy: 0.8400
# Epoch 6/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4556 - accuracy: 0.7683 - val_loss: 0.4025 - val_accuracy: 0.8500
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8338 - val_loss: 0.3622 - val_accuracy: 0.8400
# Epoch 8/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3827 - accuracy: 0.8132 - val_loss: 0.3313 - val_accuracy: 0.8500
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3384 - accuracy: 0.8477 - val_loss: 0.3155 - val_accuracy: 0.8500
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3166 - accuracy: 0.8480 - val_loss: 0.3063 - val_accuracy: 0.8400
# Epoch 11/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3053 - accuracy: 0.8683 - val_loss: 0.2870 - val_accuracy: 0.8700
# Epoch 12/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2888 - accuracy: 0.8715 - val_loss: 0.2781 - val_accuracy: 0.8700
# Epoch 13/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.8570 - val_loss: 0.2808 - val_accuracy: 0.8600
# Epoch 14/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2728 - accuracy: 0.8792 - val_loss: 0.2950 - val_accuracy: 0.8600
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2651 - accuracy: 0.8774 - val_loss: 0.2831 - val_accuracy: 0.8600
# Epoch 16/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2813 - accuracy: 0.8688 - val_loss: 0.2567 - val_accuracy: 0.8700
# Epoch 17/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2709 - accuracy: 0.8782 - val_loss: 0.2610 - val_accuracy: 0.8700
# Epoch 18/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2683 - accuracy: 0.8812 - val_loss: 0.2617 - val_accuracy: 0.8800
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2671 - accuracy: 0.8728 - val_loss: 0.2575 - val_accuracy: 0.8800
# Epoch 20/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2693 - accuracy: 0.8804 - val_loss: 0.2633 - val_accuracy: 0.8800
# Epoch 21/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.8804 - val_loss: 0.2454 - val_accuracy: 0.8900
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2509 - accuracy: 0.8835 - val_loss: 0.2569 - val_accuracy: 0.8800
# Epoch 23/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2699 - accuracy: 0.8728 - val_loss: 0.2518 - val_accuracy: 0.8900
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2457 - accuracy: 0.8874 - val_loss: 0.2467 - val_accuracy: 0.9000
# Epoch 25/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2481 - accuracy: 0.8802 - val_loss: 0.2313 - val_accuracy: 0.8900
# Epoch 26/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2396 - accuracy: 0.8915 - val_loss: 0.2468 - val_accuracy: 0.8900
# Epoch 27/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2190 - accuracy: 0.8977 - val_loss: 0.2485 - val_accuracy: 0.9000
# Epoch 28/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2140 - accuracy: 0.9113 - val_loss: 0.2691 - val_accuracy: 0.8900
# Epoch 29/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2174 - accuracy: 0.9139 - val_loss: 0.2670 - val_accuracy: 0.8800
# Epoch 30/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2325 - accuracy: 0.8996 - val_loss: 0.2618 - val_accuracy: 0.8900
# Epoch 31/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.8966 - val_loss: 0.2404 - val_accuracy: 0.9000
# Epoch 32/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2317 - accuracy: 0.8894 - val_loss: 0.2280 - val_accuracy: 0.9000
# Epoch 33/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2172 - accuracy: 0.9060 - val_loss: 0.2409 - val_accuracy: 0.9000
# Epoch 34/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2034 - accuracy: 0.9165 - val_loss: 0.2505 - val_accuracy: 0.8900
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping

# %%
print("f1_score =", f1_score(df_cf_y_test, scikit_neural.predict(df_cf_x_test)))
print("Accuracy =", scikit_neural.score(df_cf_x_test, df_cf_y_test))
# Out:
# f1_score = 0.8717948717948718
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2467 - accuracy: 0.9000
# Accuracy = 0.8999999761581421

# %%
print(f"Neural Network probability of passing ->\
 {scikit_neural.predict_proba(scaler.transform(np.array(test).reshape(1, -1)))[0][1]*100:.2f}%")
# Out:
# Neural Network probability of passing -> 79.43%

# %%
neural_model().summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 14)                210
# _________________________________________________________________
# activation_4 (Activation)    (None, 14)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                960
# _________________________________________________________________
# activation_5 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_6 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,283
# Trainable params: 3,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
pd.DataFrame(neural_model().fit(df_cf_x_train, df_cf_y_train, epochs=50, batch_size=64, verbose=0,
                       validation_data=(df_cf_x_test, df_cf_y_test), callbacks=early_stopping).history).plot()
plt.show()
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping

# %%
_ = metric.TrueNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('True Negatives =', _.result().numpy())
_ = metric.FalseNegatives()
_.update_state(df_cf_y_test, scikit_neural.predict(df_cf_x_test))
print('False Negatives =', _.result().numpy())
# Out:
# True Negatives = 56.0
# False Negatives = 8.0
